# %%
import pandas as pd
from matplotlib import pyplot as plt
import jax.numpy as np
import seaborn as sns
# %matplotlib inline

# %%
# df_relu = pd.read_csv("results/relu_L2.csv")
# df_sgmd = pd.read_csv("results/sgmd_L2.csv")
# df_relu_t = pd.read_csv("results/relu_train_loss.csv")
# df_sgmd_t = pd.read_csv("results/sgmd_train_loss.csv")

# %%
# df_relu.head()

# %%
# df_sgmd.head()

# %%
# p = sns.lineplot(data=df_relu, dashes=False)
# p.set_title("ReLU Output Layer")
# p.set(xlabel='epchocs', ylabel='eigenvalues')
# p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

# plt.show()

# %%
# p = sns.lineplot(data=df_sgmd, dashes=False)
# p.set_title("Sigmoid Output Layer")
# p.set(xlabel='epchocs', ylabel='eigenvalues')
# plt.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)
# plt.show()

# %%
# df_sgmd_t['Sigmoid'] = df_sgmd_t
# df_sgmd_t['ReLU'] = df_relu_t
# df_sgmd_t.drop('0', axis=1, inplace=True)

# %%
# p = sns.lineplot(data=df_sgmd_t, dashes=False)
# p.set_title("Error Sigmoid v/s ReLU")
# p.set(xlabel='epchocs', ylabel='ms-error')
# plt.legend(bbox_to_anchor=(1.05, 1), title="functions", loc=2, borderaxespad=0.)
# plt.show()

# %%
df_cnn_relu0 = pd.read_csv("results/cnn_relu_K0.csv")
df_cnn_relu1 = pd.read_csv("results/cnn_relu_K1.csv")
df_cnn_relu2 = pd.read_csv("results/cnn_relu_K2.csv")
df_cnn_relu3 = pd.read_csv("results/cnn_relu_K3.csv")
df_cnn_relu4 = pd.read_csv("results/cnn_relu_K4.csv")
df_cnn_relu5 = pd.read_csv("results/cnn_relu_K5.csv")
df_cnn_relu6 = pd.read_csv("results/cnn_relu_K6.csv")
df_cnn_relu7 = pd.read_csv("results/cnn_relu_K7.csv")
df_cnn_relu8 = pd.read_csv("results/cnn_relu_K8.csv")
df_cnn_relu9 = pd.read_csv("results/cnn_relu_K9.csv")

# %%
p = sns.lineplot(data=df_cnn_relu0, dashes=False)

p.set_title("ReLU Kernel 1")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu1, dashes=False)
p.set_title("ReLU Kernel 2")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu2, dashes=False)
p.set_title("ReLU Kernel 3")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu3, dashes=False)
p.set_title("ReLU Kernel 4")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu4, dashes=False)
p.set_title("ReLU Kernel 5")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu5, dashes=False)
p.set_title("ReLU Kernel 6")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu6, dashes=False)
p.set_title("ReLU Kernel 7")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu7, dashes=False)
p.set_title("ReLU Kernel 8")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu8, dashes=False)
p.set_title("ReLU Kernel 9")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu9, dashes=False)
p.set_title("ReLU Kernel 10")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()
