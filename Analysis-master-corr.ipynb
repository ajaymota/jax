# %%
import pandas as pd

# %%
import pandas as pd

dataset = 'mnist'

# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K0.csv")
df_e_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_test_class_loss.csv")
df_error_1 = pd.DataFrame(columns=["0", "1", "2", "3", "4"])
df_error_1["0"] = df_e_1["0"]
df_error_1["1"] = df_e_1["0"]
df_error_1["2"] = df_e_1["0"]
df_error_1["3"] = df_e_1["0"]
df_error_1["4"] = df_e_1["0"]
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K0.csv")
df_e_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_test_class_loss.csv")
df_error_2 = pd.DataFrame(columns=["0", "1", "2", "3", "4"])
df_error_2["0"] = df_e_2["0"]
df_error_2["1"] = df_e_2["0"]
df_error_2["2"] = df_e_2["0"]
df_error_2["3"] = df_e_2["0"]
df_error_2["4"] = df_e_2["0"]
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K0.csv")
df_e_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_test_class_loss.csv")
df_error_3 = pd.DataFrame(columns=["0", "1", "2", "3", "4"])
df_error_3["0"] = df_e_3["0"]
df_error_3["1"] = df_e_3["0"]
df_error_3["2"] = df_e_3["0"]
df_error_3["3"] = df_e_3["0"]
df_error_3["4"] = df_e_3["0"]

sgmd_k0_1 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k0_1 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k0_1 = df_cnn_relu0_3.corrwith(df_error_3)

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k1_1 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k1_1 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k1_1 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")

sgmd_k2_1 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k2_1 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k2_1 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")

sgmd_k3_1 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k3_1 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k3_1 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")

sgmd_k4_1 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k4_1 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k4_1 = df_cnn_relu0_3.corrwith(df_error_3)



###############################################################
# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")

sgmd_k5_1 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k5_1 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k5_1 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")

sgmd_k6_1 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k6_1 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k6_1 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")

sgmd_k7_1 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k7_1 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k7_1 = df_cnn_relu0_3.corrwith(df_error_3)

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")

sgmd_k8_1 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k8_1 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k8_1 = df_cnn_relu0_3.corrwith(df_error_3)

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")

sgmd_k9_1 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k9_1 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k9_1 = df_cnn_relu0_3.corrwith(df_error_3)

# %% [markdown]
# # Hand Sign MNIST

# %%
import pandas as pd

dataset = 'handsign_mnist'

# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K0.csv")
df_e_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_test_class_loss.csv")
df_error_1 = pd.DataFrame(columns=["0", "1", "2", "3", "4"])
df_error_1["0"] = df_e_1["0"]
df_error_1["1"] = df_e_1["0"]
df_error_1["2"] = df_e_1["0"]
df_error_1["3"] = df_e_1["0"]
df_error_1["4"] = df_e_1["0"]
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K0.csv")
df_e_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_test_class_loss.csv")
df_error_2 = pd.DataFrame(columns=["0", "1", "2", "3", "4"])
df_error_2["0"] = df_e_2["0"]
df_error_2["1"] = df_e_2["0"]
df_error_2["2"] = df_e_2["0"]
df_error_2["3"] = df_e_2["0"]
df_error_2["4"] = df_e_2["0"]
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K0.csv")
df_e_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_test_class_loss.csv")
df_error_3 = pd.DataFrame(columns=["0", "1", "2", "3", "4"])
df_error_3["0"] = df_e_3["0"]
df_error_3["1"] = df_e_3["0"]
df_error_3["2"] = df_e_3["0"]
df_error_3["3"] = df_e_3["0"]
df_error_3["4"] = df_e_3["0"]

sgmd_k0_2 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k0_2 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k0_2 = df_cnn_relu0_3.corrwith(df_error_3)

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k1_2 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k1_2 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k1_2 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")

sgmd_k2_2 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k2_2 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k2_2 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")

sgmd_k3_2 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k3_2 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k3_2 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")

sgmd_k4_2 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k4_2 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k4_2 = df_cnn_relu0_3.corrwith(df_error_3)



###############################################################
# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")

sgmd_k5_2 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k5_2 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k5_2 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")

sgmd_k6_2 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k6_2 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k6_2 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")

sgmd_k7_2 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k7_2 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k7_2 = df_cnn_relu0_3.corrwith(df_error_3)

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")

sgmd_k8_2 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k8_2 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k8_2 = df_cnn_relu0_3.corrwith(df_error_3)

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")

sgmd_k9_2 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k9_2 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k9_2 = df_cnn_relu0_3.corrwith(df_error_3)

# %% [markdown]
# # Fashion MNIST

# %%
import pandas as pd

dataset = 'fashion_mnist'

# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K0.csv")
df_e_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_test_class_loss.csv")
df_error_1 = pd.DataFrame(columns=["0", "1", "2", "3", "4"])
df_error_1["0"] = df_e_1["0"]
df_error_1["1"] = df_e_1["0"]
df_error_1["2"] = df_e_1["0"]
df_error_1["3"] = df_e_1["0"]
df_error_1["4"] = df_e_1["0"]
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K0.csv")
df_e_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_test_class_loss.csv")
df_error_2 = pd.DataFrame(columns=["0", "1", "2", "3", "4"])
df_error_2["0"] = df_e_2["0"]
df_error_2["1"] = df_e_2["0"]
df_error_2["2"] = df_e_2["0"]
df_error_2["3"] = df_e_2["0"]
df_error_2["4"] = df_e_2["0"]
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K0.csv")
df_e_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_test_class_loss.csv")
df_error_3 = pd.DataFrame(columns=["0", "1", "2", "3", "4"])
df_error_3["0"] = df_e_3["0"]
df_error_3["1"] = df_e_3["0"]
df_error_3["2"] = df_e_3["0"]
df_error_3["3"] = df_e_3["0"]
df_error_3["4"] = df_e_3["0"]

sgmd_k0_3 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k0_3 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k0_3 = df_cnn_relu0_3.corrwith(df_error_3)

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k1_3 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k1_3 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k1_3 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")

sgmd_k2_3 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k2_3 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k2_3 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")

sgmd_k3_3 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k3_3 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k3_3 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")

sgmd_k4_3 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k4_3 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k4_3 = df_cnn_relu0_3.corrwith(df_error_3)



###############################################################
# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")

sgmd_k5_3 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k5_3 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k5_3 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")

sgmd_k6_3 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k6_3 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k6_3 = df_cnn_relu0_3.corrwith(df_error_3)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")

sgmd_k7_3 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k7_3 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k7_3 = df_cnn_relu0_3.corrwith(df_error_3)

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")

sgmd_k8_3 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k8_3 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k8_3 = df_cnn_relu0_3.corrwith(df_error_3)

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")

sgmd_k9_3 = df_cnn_relu0_1.corrwith(df_error_1)
tanh_k9_3 = df_cnn_relu0_2.corrwith(df_error_2)
relu_k9_3 = df_cnn_relu0_3.corrwith(df_error_3)

# %% [markdown]
# # Corr-Map (Error Rates)

# %%
import numpy as np

lst = [[sgmd_k0_1.corr(sgmd_k0_2), sgmd_k1_1.corr(sgmd_k1_2), sgmd_k2_1.corr(sgmd_k2_2),
        sgmd_k3_1.corr(sgmd_k3_2), sgmd_k4_1.corr(sgmd_k4_2), sgmd_k5_1.corr(sgmd_k5_2),
        sgmd_k6_1.corr(sgmd_k6_2), sgmd_k7_1.corr(sgmd_k7_2), sgmd_k8_1.corr(sgmd_k8_2),
        sgmd_k9_1.corr(sgmd_k9_2)],
       [sgmd_k0_2.corr(sgmd_k0_3), sgmd_k1_2.corr(sgmd_k1_3), sgmd_k2_2.corr(sgmd_k2_3),
        sgmd_k3_2.corr(sgmd_k3_3), sgmd_k4_2.corr(sgmd_k4_3), sgmd_k5_2.corr(sgmd_k5_3),
        sgmd_k6_2.corr(sgmd_k6_3), sgmd_k7_2.corr(sgmd_k7_3), sgmd_k8_2.corr(sgmd_k8_3),
        sgmd_k9_2.corr(sgmd_k9_3)],
       [sgmd_k0_3.corr(sgmd_k0_1), sgmd_k1_3.corr(sgmd_k1_1), sgmd_k2_3.corr(sgmd_k2_1),
        sgmd_k3_3.corr(sgmd_k3_1), sgmd_k4_3.corr(sgmd_k4_1), sgmd_k5_3.corr(sgmd_k5_1),
        sgmd_k6_3.corr(sgmd_k6_1), sgmd_k7_3.corr(sgmd_k7_1), sgmd_k8_3.corr(sgmd_k8_1),
        sgmd_k9_3.corr(sgmd_k9_1)]]

lst = np.array(lst).T.tolist()

df_1 = pd.DataFrame(lst, columns =[0, 1, 2])  

df_1 = df_1.rename(columns={0: "mnist to hand", 1: "hand to fash", 2: "fash to mnist"})
df_1 = df_1.rename(index={  "0": "Kernel 0", "1": "Kernel 1", "2": "Kernel 2",
                            "3": "Kernel 3", "4": "Kernel 4", "5": "Kernel 5",
                            "6": "Kernel 6", "7": "Kernel 7", "8": "Kernel 8",
                            "9": "Kernel 9"})

print('sigmoid to error')
df_1
# Out:
# sigmoid to error
#    mnist to hand  hand to fash  fash to mnist
# 0       0.199633     -0.683323       0.134444
# 1       0.677378     -0.994516      -0.599993
# 2       0.567550      0.288904       0.287519
# 3       0.464325     -0.633545      -0.962543
# 4       0.242336     -0.326084      -0.933889
# 5       0.989024      0.456776       0.381551
# 6      -0.739264     -0.560119       0.907779
# 7       0.388458     -0.199295      -0.202153
# 8      -0.574125      0.674235      -0.457104
# 9       0.430292     -0.158240      -0.163722

# %%
lst = [[tanh_k0_1.corr(tanh_k0_2), tanh_k1_1.corr(tanh_k1_2), tanh_k2_1.corr(tanh_k2_2),
        tanh_k3_1.corr(tanh_k3_2), tanh_k4_1.corr(tanh_k4_2), tanh_k5_1.corr(tanh_k5_2),
        tanh_k6_1.corr(tanh_k6_2), tanh_k7_1.corr(tanh_k7_2), tanh_k8_1.corr(tanh_k8_2),
        tanh_k9_1.corr(tanh_k9_2)],
       [tanh_k0_2.corr(tanh_k0_3), tanh_k1_2.corr(tanh_k1_3), tanh_k2_2.corr(tanh_k2_3),
        tanh_k3_2.corr(tanh_k3_3), tanh_k4_2.corr(tanh_k4_3), tanh_k5_2.corr(tanh_k5_3),
        tanh_k6_2.corr(tanh_k6_3), tanh_k7_2.corr(tanh_k7_3), tanh_k8_2.corr(tanh_k8_3),
        tanh_k9_2.corr(tanh_k9_3)],
       [tanh_k0_3.corr(tanh_k0_1), tanh_k1_3.corr(tanh_k1_1), tanh_k2_3.corr(tanh_k2_1),
        tanh_k3_3.corr(tanh_k3_1), tanh_k4_3.corr(tanh_k4_1), tanh_k5_3.corr(tanh_k5_1),
        tanh_k6_3.corr(tanh_k6_1), tanh_k7_3.corr(tanh_k7_1), tanh_k8_3.corr(tanh_k8_1),
        tanh_k9_3.corr(tanh_k9_1)]]

lst = np.array(lst).T.tolist()

df_2 = pd.DataFrame(lst, columns =[0, 1, 2])  

df_2 = df_2.rename(columns={0: "mnist to hand", 1: "hand to fash", 2: "fash to mnist"})
df_2 = df_2.rename(index={"0": "Kernel 0", "1": "Kernel 1", "2": "Kernel 2",
                            "3": "Kernel 3", "4": "Kernel 4", "5": "Kernel 5",
                            "6": "Kernel 6", "7": "Kernel 7", "8": "Kernel 8",
                            "9": "Kernel 9"})

print('tanh to error')
df_2
# Out:
# tanh to error
#    mnist to hand  hand to fash  fash to mnist
# 0       0.355905      0.531271       0.654906
# 1      -0.195404      0.850134      -0.313467
# 2       0.611325      0.995860       0.551657
# 3       0.043133      0.356541       0.591599
# 4       0.667169      0.540521       0.131239
# 5       0.960571      0.637215       0.545123
# 6       0.935908     -0.364460      -0.013084
# 7       0.413867     -0.146330      -0.630255
# 8       0.476248     -0.152352       0.461970
# 9       0.419838     -0.027869       0.494084

# %%
lst = [[relu_k0_1.corr(relu_k0_2), relu_k1_1.corr(relu_k1_2), relu_k2_1.corr(relu_k2_2),
        relu_k3_1.corr(relu_k3_2), relu_k4_1.corr(relu_k4_2), relu_k5_1.corr(relu_k5_2),
        relu_k6_1.corr(relu_k6_2), relu_k7_1.corr(relu_k7_2), relu_k8_1.corr(relu_k8_2),
        relu_k9_1.corr(relu_k9_2)],
       [relu_k0_2.corr(relu_k0_3), relu_k1_2.corr(relu_k1_3), relu_k2_2.corr(relu_k2_3),
        relu_k3_2.corr(relu_k3_3), relu_k4_2.corr(relu_k4_3), relu_k5_2.corr(relu_k5_3),
        relu_k6_2.corr(relu_k6_3), relu_k7_2.corr(relu_k7_3), relu_k8_2.corr(relu_k8_3),
        relu_k9_2.corr(relu_k9_3)],
       [relu_k0_3.corr(relu_k0_1), relu_k1_3.corr(relu_k1_1), relu_k2_3.corr(relu_k2_1),
        relu_k3_3.corr(relu_k3_1), relu_k4_3.corr(relu_k4_1), relu_k5_3.corr(relu_k5_1),
        relu_k6_3.corr(relu_k6_1), relu_k7_3.corr(relu_k7_1), relu_k8_3.corr(relu_k8_1),
        relu_k9_3.corr(relu_k9_1)]]

lst = np.array(lst).T.tolist()

df_3 = pd.DataFrame(lst, columns =[0, 1, 2])  

df_3 = df_3.rename(columns={0: "mnist to hand", 1: "hand to fash", 2: "fash to mnist"})
df_3 = df_3.rename(index={"0": "Kernel 0", "1": "Kernel 1", "2": "Kernel 2",
                            "3": "Kernel 3", "4": "Kernel 4", "5": "Kernel 5",
                            "6": "Kernel 6", "7": "Kernel 7", "8": "Kernel 8",
                            "9": "Kernel 9"})

print('relu to error')
df_3
# Out:
# relu to error
#    mnist to hand  hand to fash  fash to mnist
# 0       0.138242      0.870402      -0.118226
# 1      -0.938327      0.153178      -0.091283
# 2      -0.662967     -0.588523       0.101259
# 3       0.947526      0.622872       0.512758
# 4       0.762969      0.766594       0.628984
# 5       0.999186     -0.474795      -0.449676
# 6      -0.406658     -0.855320      -0.092454
# 7       0.031225      0.419954      -0.801544
# 8      -0.400697      0.422661       0.658022
# 9       0.990290      0.745623       0.831020

# %%
# print("sgmd to tanh")
# print()
# df_1.corrwith(df_2)

# %%
# print("tanh to relu")
# print()
# df_2.corrwith(df_3)

# %%
# print("relu to sgmd")
# print()
# df_3.corrwith(df_1)

# %%
print("Corr: sgmd to error")
print()
print('mnist to hand: ', df_1['mnist to hand'].abs().mean())
print('hand to fash: ', df_1['hand to fash'].abs().mean())
print('fash to mnist: ', df_1['fash to mnist'].abs().mean())
print()
print()

print("Corr: tanh to error")
print()
print('mnist to hand: ', df_2['mnist to hand'].abs().mean())
print('hand to fash: ', df_2['hand to fash'].abs().mean())
print('fash to mnist: ', df_2['fash to mnist'].abs().mean())
print()
print()

print("Corr: relu to error")
print()
print('mnist to hand: ', df_3['mnist to hand'].abs().mean())
print('hand to fash: ', df_3['hand to fash'].abs().mean())
print('fash to mnist: ', df_3['fash to mnist'].abs().mean())
print()
print()
# Out:
# Corr: sgmd to error
#
# mnist to hand:  0.5272385750377857
# hand to fash:  0.49750367302314624
# fash to mnist:  0.5030695688546619
#
#
# Corr: tanh to error
#
# mnist to hand:  0.5079367455250687
# hand to fash:  0.4602553964090916
# fash to mnist:  0.43873835331294375
#
#
# Corr: relu to error
#
# mnist to hand:  0.6278088003749149
# hand to fash:  0.5919921788176887
# fash to mnist:  0.42852264216712455
