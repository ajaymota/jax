# %%
import pandas as pd
import numpy as np

# %%
def calc_dist(df1, df2):
    x = df1.corrwith(df2)
    x[0] = np.linalg.norm(df1['0'].to_numpy()-df2['0'].to_numpy())
    x[1] = np.linalg.norm(df1['1'].to_numpy()-df2['1'].to_numpy())
    x[2] = np.linalg.norm(df1['2'].to_numpy()-df2['2'].to_numpy())
    x[3] = np.linalg.norm(df1['3'].to_numpy()-df2['3'].to_numpy())
    x[4] = np.linalg.norm(df1['4'].to_numpy()-df2['4'].to_numpy())
    return x

# %%
dataset = 'mnist'

# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k0_1 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k0_1 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k0_1 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k1_1 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k1_1 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k1_1 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")

sgmd_k2_1 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k2_1 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k2_1 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")

sgmd_k3_1 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k3_1 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k3_1 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")

sgmd_k4_1 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k4_1 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k4_1 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)



###############################################################
# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")

sgmd_k5_1 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k5_1 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k5_1 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")

sgmd_k6_1 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k6_1 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k6_1 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")

sgmd_k7_1 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k7_1 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k7_1 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")

sgmd_k8_1 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k8_1 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k8_1 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")

sgmd_k9_1 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k9_1 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k9_1 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)

# %% [markdown]
# # Hand Sign MNIST

# %%
dataset = 'handsign_mnist'

# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k0_2 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k0_2 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k0_2 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k1_2 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k1_2 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k1_2 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")

sgmd_k2_2 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k2_2 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k2_2 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")

sgmd_k3_2 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k3_2 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k3_2 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")

sgmd_k4_2 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k4_2 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k4_2 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)



###############################################################
# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")

sgmd_k5_2 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k5_2 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k5_2 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")

sgmd_k6_2 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k6_2 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k6_2 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")

sgmd_k7_2 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k7_2 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k7_2 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")

sgmd_k8_2 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k8_2 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k8_2 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")

sgmd_k9_2 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k9_2 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k9_2 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)

# %% [markdown]
# # Fashion MNIST

# %%
dataset = 'fashion_mnist'

# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k0_3 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k0_3 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k0_3 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k1_3 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k1_3 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k1_3 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")

sgmd_k2_3 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k2_3 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k2_3 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")

sgmd_k3_3 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k3_3 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k3_3 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")

sgmd_k4_3 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k4_3 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k4_3 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)



###############################################################
# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")

sgmd_k5_3 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k5_3 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k5_3 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")

sgmd_k6_3 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k6_3 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k6_3 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")

sgmd_k7_3 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k7_3 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k7_3 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")

sgmd_k8_3 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k8_3 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k8_3 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")

sgmd_k9_3 = calc_dist(df_cnn_relu0_1, df_cnn_relu0_2)
tanh_k9_3 = calc_dist(df_cnn_relu0_2, df_cnn_relu0_3)
relu_k9_3 = calc_dist(df_cnn_relu0_3, df_cnn_relu0_1)

# %% [markdown]
# # Corr-Map (Error Rates)

# %%
import numpy as np

lst = [[sgmd_k0_1.corr(sgmd_k0_2), sgmd_k1_1.corr(sgmd_k1_2), sgmd_k2_1.corr(sgmd_k2_2),
        sgmd_k3_1.corr(sgmd_k3_2), sgmd_k4_1.corr(sgmd_k4_2), sgmd_k5_1.corr(sgmd_k5_2),
        sgmd_k6_1.corr(sgmd_k6_2), sgmd_k7_1.corr(sgmd_k7_2), sgmd_k8_1.corr(sgmd_k8_2),
        sgmd_k9_1.corr(sgmd_k9_2)],
       [sgmd_k0_2.corr(sgmd_k0_3), sgmd_k1_2.corr(sgmd_k1_3), sgmd_k2_2.corr(sgmd_k2_3),
        sgmd_k3_2.corr(sgmd_k3_3), sgmd_k4_2.corr(sgmd_k4_3), sgmd_k5_2.corr(sgmd_k5_3),
        sgmd_k6_2.corr(sgmd_k6_3), sgmd_k7_2.corr(sgmd_k7_3), sgmd_k8_2.corr(sgmd_k8_3),
        sgmd_k9_2.corr(sgmd_k9_3)],
       [sgmd_k0_3.corr(sgmd_k0_1), sgmd_k1_3.corr(sgmd_k1_1), sgmd_k2_3.corr(sgmd_k2_1),
        sgmd_k3_3.corr(sgmd_k3_1), sgmd_k4_3.corr(sgmd_k4_1), sgmd_k5_3.corr(sgmd_k5_1),
        sgmd_k6_3.corr(sgmd_k6_1), sgmd_k7_3.corr(sgmd_k7_1), sgmd_k8_3.corr(sgmd_k8_1),
        sgmd_k9_3.corr(sgmd_k9_1)]]

lst = np.array(lst).T.tolist()

df_1 = pd.DataFrame(lst, columns =[0, 1, 2])  

df_1 = df_1.rename(columns={0: "mnist to hand", 1: "hand to fash", 2: "fash to mnist"})
df_1 = df_1.rename(index={  "0": "Kernel 0", "1": "Kernel 1", "2": "Kernel 2",
                            "3": "Kernel 3", "4": "Kernel 4", "5": "Kernel 5",
                            "6": "Kernel 6", "7": "Kernel 7", "8": "Kernel 8",
                            "9": "Kernel 9"})

print('sgmd to tanh')
df_1
# Out:
# sgmd to tanh
#    mnist to hand  hand to fash  fash to mnist
# 0       0.814687     -0.311105      -0.574312
# 1       0.814687     -0.311105      -0.574312
# 2       0.937337     -0.750264      -0.580546
# 3      -0.008552      0.437531      -0.080273
# 4       0.449810      0.294648      -0.126505
# 5       0.927656      0.579953       0.281061
# 6       0.553751     -0.980524      -0.702731
# 7       0.925566     -0.135891       0.164434
# 8       0.319237     -0.228136      -0.061877
# 9       0.270091     -0.532983       0.549983

# %%
lst = [[tanh_k0_1.corr(tanh_k0_2), tanh_k1_1.corr(tanh_k1_2), tanh_k2_1.corr(tanh_k2_2),
        tanh_k3_1.corr(tanh_k3_2), tanh_k4_1.corr(tanh_k4_2), tanh_k5_1.corr(tanh_k5_2),
        tanh_k6_1.corr(tanh_k6_2), tanh_k7_1.corr(tanh_k7_2), tanh_k8_1.corr(tanh_k8_2),
        tanh_k9_1.corr(tanh_k9_2)],
       [tanh_k0_2.corr(tanh_k0_3), tanh_k1_2.corr(tanh_k1_3), tanh_k2_2.corr(tanh_k2_3),
        tanh_k3_2.corr(tanh_k3_3), tanh_k4_2.corr(tanh_k4_3), tanh_k5_2.corr(tanh_k5_3),
        tanh_k6_2.corr(tanh_k6_3), tanh_k7_2.corr(tanh_k7_3), tanh_k8_2.corr(tanh_k8_3),
        tanh_k9_2.corr(tanh_k9_3)],
       [tanh_k0_3.corr(tanh_k0_1), tanh_k1_3.corr(tanh_k1_1), tanh_k2_3.corr(tanh_k2_1),
        tanh_k3_3.corr(tanh_k3_1), tanh_k4_3.corr(tanh_k4_1), tanh_k5_3.corr(tanh_k5_1),
        tanh_k6_3.corr(tanh_k6_1), tanh_k7_3.corr(tanh_k7_1), tanh_k8_3.corr(tanh_k8_1),
        tanh_k9_3.corr(tanh_k9_1)]]

lst = np.array(lst).T.tolist()

df_2 = pd.DataFrame(lst, columns =[0, 1, 2])  

df_2 = df_2.rename(columns={0: "mnist to hand", 1: "hand to fash", 2: "fash to mnist"})
df_2 = df_2.rename(index={"0": "Kernel 0", "1": "Kernel 1", "2": "Kernel 2",
                            "3": "Kernel 3", "4": "Kernel 4", "5": "Kernel 5",
                            "6": "Kernel 6", "7": "Kernel 7", "8": "Kernel 8",
                            "9": "Kernel 9"})

print('tanh to relu')
df_2
# Out:
# tanh to relu
#    mnist to hand  hand to fash  fash to mnist
# 0       0.747813      0.723235       0.834974
# 1       0.747813      0.723235       0.834974
# 2       0.934842     -0.645452      -0.654428
# 3       0.253943     -0.158617      -0.428364
# 4      -0.156158      0.171700       0.514407
# 5       0.965100      0.977147       0.998324
# 6       0.115907      0.135208      -0.663037
# 7       0.245355      0.383253      -0.096097
# 8       0.690899      0.403627      -0.297636
# 9       0.950281      0.858879       0.941804

# %%
lst = [[relu_k0_1.corr(relu_k0_2), relu_k1_1.corr(relu_k1_2), relu_k2_1.corr(relu_k2_2),
        relu_k3_1.corr(relu_k3_2), relu_k4_1.corr(relu_k4_2), relu_k5_1.corr(relu_k5_2),
        relu_k6_1.corr(relu_k6_2), relu_k7_1.corr(relu_k7_2), relu_k8_1.corr(relu_k8_2),
        relu_k9_1.corr(relu_k9_2)],
       [relu_k0_2.corr(relu_k0_3), relu_k1_2.corr(relu_k1_3), relu_k2_2.corr(relu_k2_3),
        relu_k3_2.corr(relu_k3_3), relu_k4_2.corr(relu_k4_3), relu_k5_2.corr(relu_k5_3),
        relu_k6_2.corr(relu_k6_3), relu_k7_2.corr(relu_k7_3), relu_k8_2.corr(relu_k8_3),
        relu_k9_2.corr(relu_k9_3)],
       [relu_k0_3.corr(relu_k0_1), relu_k1_3.corr(relu_k1_1), relu_k2_3.corr(relu_k2_1),
        relu_k3_3.corr(relu_k3_1), relu_k4_3.corr(relu_k4_1), relu_k5_3.corr(relu_k5_1),
        relu_k6_3.corr(relu_k6_1), relu_k7_3.corr(relu_k7_1), relu_k8_3.corr(relu_k8_1),
        relu_k9_3.corr(relu_k9_1)]]

lst = np.array(lst).T.tolist()

df_3 = pd.DataFrame(lst, columns =[0, 1, 2])   

df_3 = df_3.rename(columns={0: "mnist to hand", 1: "hand to fash", 2: "fash to mnist"})
df_3 = df_3.rename(index={"0": "Kernel 0", "1": "Kernel 1", "2": "Kernel 2",
                            "3": "Kernel 3", "4": "Kernel 4", "5": "Kernel 5",
                            "6": "Kernel 6", "7": "Kernel 7", "8": "Kernel 8",
                            "9": "Kernel 9"})

print('relu to sgmd')
df_3
# Out:
# relu to sgmd
#    mnist to hand  hand to fash  fash to mnist
# 0       0.421111      0.578265      -0.240879
# 1       0.421111      0.578265      -0.240879
# 2       0.420861     -0.668651      -0.051930
# 3       0.596094      0.657404       0.079842
# 4       0.718355      0.365716      -0.119793
# 5       0.989944      0.989852       0.999424
# 6       0.727757     -0.964031      -0.585718
# 7       0.724711     -0.032249       0.203838
# 8       0.890657     -0.419980      -0.718024
# 9       0.997984      0.999477       0.995543

# %%
# print("sgmd to tanh")
# print()
# df_1.corrwith(df_2)

# %%
# print("tanh to relu")
# print()
# df_2.corrwith(df_3)

# %%
# print("relu to sgmd")
# print()
# df_3.corrwith(df_1)

# %%
print("Corr: sgmd to tanh")
print()
print('mnist to hand: ', df_1['mnist to hand'].abs().mean())
print('hand to fash: ', df_1['hand to fash'].abs().mean())
print('fash to mnist: ', df_1['fash to mnist'].abs().mean())
print()
print()

print("Corr: tanh to relu")
print()
print('mnist to hand: ', df_2['mnist to hand'].abs().mean())
print('hand to fash: ', df_2['hand to fash'].abs().mean())
print('fash to mnist: ', df_2['fash to mnist'].abs().mean())
print()
print()

print("Corr: relu to sgmd")
print()
print('mnist to hand: ', df_3['mnist to hand'].abs().mean())
print('hand to fash: ', df_3['hand to fash'].abs().mean())
print('fash to mnist: ', df_3['fash to mnist'].abs().mean())
print()
print()
# Out:
# Corr: sgmd to tanh
#
# mnist to hand:  0.60213747761191
# hand to fash:  0.45621398326662066
# fash to mnist:  0.3696033533315532
#
#
# Corr: tanh to relu
#
# mnist to hand:  0.5808110179734324
# hand to fash:  0.518035395626433
# fash to mnist:  0.6264044763012849
#
#
# Corr: relu to sgmd
#
# mnist to hand:  0.6908583592866698
# hand to fash:  0.6253890097216771
# fash to mnist:  0.4235869614044949
