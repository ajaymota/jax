# %%
import pandas as pd
from matplotlib import pyplot as plt
import jax.numpy as np
import seaborn as sns

# %%
activator = "relu"
dropout_rate = 0.8

# %%
df_cnn_relu_train = pd.read_csv("results/dropout/" + str(dropout_rate) + "/" + activator + "/cnn_train_loss.csv")
df_cnn_relu_test = pd.read_csv("results/dropout/" + str(dropout_rate) + "/" + activator + "/cnn_test_loss.csv")
df_cnn_relu_test_class = pd.read_csv("results/dropout/" + str(dropout_rate) + "/" + activator + "/cnn_test_class_loss.csv")

# %%
df_cnn_relu_train['train'] = df_cnn_relu_train
df_cnn_relu_train['test'] = df_cnn_relu_test
df_cnn_relu_train['classification'] = df_cnn_relu_test_class
df_cnn_relu_train.drop('0', axis=1, inplace=True)

# %%
p = sns.lineplot(data=df_cnn_relu_train, dashes=False)
p.set_title("Error - train v/s test v/s classification")
p.set(xlabel='epchocs', ylabel='error')
plt.legend(bbox_to_anchor=(1.05, 1), title="type", loc=2, borderaxespad=0.)
plt.show()

# %%
df_cnn_relu0 = pd.read_csv("results/dropout/" + str(dropout_rate) + "/" + activator + "/cnn_K0.csv")
df_cnn_relu1 = pd.read_csv("results/dropout/" + str(dropout_rate) + "/" + activator + "/cnn_K1.csv")
df_cnn_relu2 = pd.read_csv("results/dropout/" + str(dropout_rate) + "/" + activator + "/cnn_K2.csv")
df_cnn_relu3 = pd.read_csv("results/dropout/" + str(dropout_rate) + "/" + activator + "/cnn_K3.csv")
df_cnn_relu4 = pd.read_csv("results/dropout/" + str(dropout_rate) + "/" + activator + "/cnn_K4.csv")
df_cnn_relu5 = pd.read_csv("results/dropout/" + str(dropout_rate) + "/" + activator + "/cnn_K5.csv")
df_cnn_relu6 = pd.read_csv("results/dropout/" + str(dropout_rate) + "/" + activator + "/cnn_K6.csv")
df_cnn_relu7 = pd.read_csv("results/dropout/" + str(dropout_rate) + "/" + activator + "/cnn_K7.csv")
df_cnn_relu8 = pd.read_csv("results/dropout/" + str(dropout_rate) + "/" + activator + "/cnn_K8.csv")
df_cnn_relu9 = pd.read_csv("results/dropout/" + str(dropout_rate) + "/" + activator + "/cnn_K9.csv")

# %%
p = sns.lineplot(data=df_cnn_relu0, dashes=False)
p.set_title(activator + " Kernel 1 " + str(dropout_rate))
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)
plt.savefig("figures/" + activator + " Kernel 1 " + str(dropout_rate) + '.png')
plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu1, dashes=False)
p.set_title(activator + " Kernel 2 " + str(dropout_rate))
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)
plt.savefig("figures/" + activator + " Kernel 2 " + str(dropout_rate) + '.png')
plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu2, dashes=False)
p.set_title(activator + " Kernel 3 " + str(dropout_rate))
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)
plt.savefig("figures/" + activator + " Kernel 3 " + str(dropout_rate) + '.png')
plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu3, dashes=False)
p.set_title(activator + " Kernel 4 " + str(dropout_rate))
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)
plt.savefig("figures/" + activator + " Kernel 4 " + str(dropout_rate) + '.png')
plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu4, dashes=False)
p.set_title(activator + " Kernel 5 " + str(dropout_rate))
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)
plt.savefig("figures/" + activator + " Kernel 5 " + str(dropout_rate) + '.png')
plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu5, dashes=False)
p.set_title(activator + " Kernel 6 " + str(dropout_rate))
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)
plt.savefig("figures/" + activator + " Kernel 6 " + str(dropout_rate) + '.png')
plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu6, dashes=False)
p.set_title(activator + " Kernel 7 " + str(dropout_rate))
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)
plt.savefig("figures/" + activator + " Kernel 7 " + str(dropout_rate) + '.png')
plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu7, dashes=False)
p.set_title(activator + " Kernel 8 " + str(dropout_rate))
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)
plt.savefig("figures/" + activator + " Kernel 8 " + str(dropout_rate) + '.png')
plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu8, dashes=False)
p.set_title(activator + " Kernel 9 " + str(dropout_rate))
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)
plt.savefig("figures/" + activator + " Kernel 9 " + str(dropout_rate) + '.png')
plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu9, dashes=False)
p.set_title(activator + " Kernel 10 " + str(dropout_rate))
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)
plt.savefig("figures/" + activator + " Kernel 10 " + str(dropout_rate) + '.png')
plt.show()

# %%
print(df_cnn_relu0['0'].corr(df_cnn_relu_train['classification']) )
print(df_cnn_relu0['1'].corr(df_cnn_relu_train['classification']) )
print(df_cnn_relu0['2'].corr(df_cnn_relu_train['classification']) )
print(df_cnn_relu0['3'].corr(df_cnn_relu_train['classification']) )
print(df_cnn_relu0['4'].corr(df_cnn_relu_train['classification']) )
# Out:
# 0.9543368294477245
# 0.992703730412034
# 0.9151741073632403
# -0.9678223301818383
# -0.8392843680120163

# %%
df_cnn_relu0.corrwith(df_cnn_relu9, axis=0)
# Out:
# 0   -0.999305
# 1    0.961706
# 2   -0.991811
# 3    0.998882
# 4    0.577878
# dtype: float64
