# %%
import pandas as pd
from matplotlib import pyplot as plt
import jax.numpy as np
import seaborn as sns

# %%
activator = "sgmd"


df_cnn_relu0 = pd.read_csv("results/" + activator + "/cnn_K0.csv")
df_cnn_relu1 = pd.read_csv("results/" + activator + "/cnn_K1.csv")
df_cnn_relu2 = pd.read_csv("results/" + activator + "/cnn_K2.csv")
df_cnn_relu3 = pd.read_csv("results/" + activator + "/cnn_K3.csv")
df_cnn_relu4 = pd.read_csv("results/" + activator + "/cnn_K4.csv")
df_cnn_relu5 = pd.read_csv("results/" + activator + "/cnn_K5.csv")
df_cnn_relu6 = pd.read_csv("results/" + activator + "/cnn_K6.csv")
df_cnn_relu7 = pd.read_csv("results/" + activator + "/cnn_K7.csv")
df_cnn_relu8 = pd.read_csv("results/" + activator + "/cnn_K8.csv")
df_cnn_relu9 = pd.read_csv("results/" + activator + "/cnn_K9.csv")

df_1 = pd.DataFrame(columns=[])
df_2 = pd.DataFrame(columns=[])
df_3 = pd.DataFrame(columns=[])
df_4 = pd.DataFrame(columns=[])
df_5 = pd.DataFrame(columns=[])

df_1 = df_1.append(pd.Series([df_cnn_relu0.iloc[-1][0], df_cnn_relu1.iloc[-1][0], df_cnn_relu2.iloc[-1][0],
                       df_cnn_relu3.iloc[-1][0], df_cnn_relu4.iloc[-1][0], df_cnn_relu5.iloc[-1][0],
                       df_cnn_relu6.iloc[-1][0], df_cnn_relu7.iloc[-1][0], df_cnn_relu8.iloc[-1][0],
                       df_cnn_relu9.iloc[-1][0]]),ignore_index=True)

df_2 = df_2.append(pd.Series([df_cnn_relu0.iloc[-1][1], df_cnn_relu1.iloc[-1][1], df_cnn_relu2.iloc[-1][1],
                       df_cnn_relu3.iloc[-1][1], df_cnn_relu4.iloc[-1][1], df_cnn_relu5.iloc[-1][1],
                       df_cnn_relu6.iloc[-1][1], df_cnn_relu7.iloc[-1][1], df_cnn_relu8.iloc[-1][1],
                       df_cnn_relu9.iloc[-1][1]]),ignore_index=True)

df_3 = df_3.append(pd.Series([df_cnn_relu0.iloc[-1][2], df_cnn_relu1.iloc[-1][2], df_cnn_relu2.iloc[-1][2],
                       df_cnn_relu3.iloc[-1][2], df_cnn_relu4.iloc[-1][2], df_cnn_relu5.iloc[-1][2],
                       df_cnn_relu6.iloc[-1][2], df_cnn_relu7.iloc[-1][2], df_cnn_relu8.iloc[-1][2],
                       df_cnn_relu9.iloc[-1][2]]),ignore_index=True)

df_4 = df_4.append(pd.Series([df_cnn_relu0.iloc[-1][3], df_cnn_relu1.iloc[-1][3], df_cnn_relu2.iloc[-1][3],
                       df_cnn_relu3.iloc[-1][3], df_cnn_relu4.iloc[-1][3], df_cnn_relu5.iloc[-1][3],
                       df_cnn_relu6.iloc[-1][3], df_cnn_relu7.iloc[-1][3], df_cnn_relu8.iloc[-1][3],
                       df_cnn_relu9.iloc[-1][3]]),ignore_index=True)

df_5 = df_5.append(pd.Series([df_cnn_relu0.iloc[-1][3], df_cnn_relu1.iloc[-1][3], df_cnn_relu2.iloc[-1][3],
                       df_cnn_relu3.iloc[-1][3], df_cnn_relu4.iloc[-1][3], df_cnn_relu5.iloc[-1][3],
                       df_cnn_relu6.iloc[-1][3], df_cnn_relu7.iloc[-1][3], df_cnn_relu8.iloc[-1][3],
                       df_cnn_relu9.iloc[-1][3]]),ignore_index=True)

activator = "tanh"

df_cnn_relu0 = pd.read_csv("results/" + activator + "/cnn_K0.csv")
df_cnn_relu1 = pd.read_csv("results/" + activator + "/cnn_K1.csv")
df_cnn_relu2 = pd.read_csv("results/" + activator + "/cnn_K2.csv")
df_cnn_relu3 = pd.read_csv("results/" + activator + "/cnn_K3.csv")
df_cnn_relu4 = pd.read_csv("results/" + activator + "/cnn_K4.csv")
df_cnn_relu5 = pd.read_csv("results/" + activator + "/cnn_K5.csv")
df_cnn_relu6 = pd.read_csv("results/" + activator + "/cnn_K6.csv")
df_cnn_relu7 = pd.read_csv("results/" + activator + "/cnn_K7.csv")
df_cnn_relu8 = pd.read_csv("results/" + activator + "/cnn_K8.csv")
df_cnn_relu9 = pd.read_csv("results/" + activator + "/cnn_K9.csv")

df_1 = df_1.append(pd.Series([df_cnn_relu0.iloc[-1][0], df_cnn_relu1.iloc[-1][0], df_cnn_relu2.iloc[-1][0],
                       df_cnn_relu3.iloc[-1][0], df_cnn_relu4.iloc[-1][0], df_cnn_relu5.iloc[-1][0],
                       df_cnn_relu6.iloc[-1][0], df_cnn_relu7.iloc[-1][0], df_cnn_relu8.iloc[-1][0],
                       df_cnn_relu9.iloc[-1][0]]),ignore_index=True)

df_2 = df_2.append(pd.Series([df_cnn_relu0.iloc[-1][1], df_cnn_relu1.iloc[-1][1], df_cnn_relu2.iloc[-1][1],
                       df_cnn_relu3.iloc[-1][1], df_cnn_relu4.iloc[-1][1], df_cnn_relu5.iloc[-1][1],
                       df_cnn_relu6.iloc[-1][1], df_cnn_relu7.iloc[-1][1], df_cnn_relu8.iloc[-1][1],
                       df_cnn_relu9.iloc[-1][1]]),ignore_index=True)

df_3 = df_3.append(pd.Series([df_cnn_relu0.iloc[-1][2], df_cnn_relu1.iloc[-1][2], df_cnn_relu2.iloc[-1][2],
                       df_cnn_relu3.iloc[-1][2], df_cnn_relu4.iloc[-1][2], df_cnn_relu5.iloc[-1][2],
                       df_cnn_relu6.iloc[-1][2], df_cnn_relu7.iloc[-1][2], df_cnn_relu8.iloc[-1][2],
                       df_cnn_relu9.iloc[-1][2]]),ignore_index=True)

df_4 = df_4.append(pd.Series([df_cnn_relu0.iloc[-1][3], df_cnn_relu1.iloc[-1][3], df_cnn_relu2.iloc[-1][3],
                       df_cnn_relu3.iloc[-1][3], df_cnn_relu4.iloc[-1][3], df_cnn_relu5.iloc[-1][3],
                       df_cnn_relu6.iloc[-1][3], df_cnn_relu7.iloc[-1][3], df_cnn_relu8.iloc[-1][3],
                       df_cnn_relu9.iloc[-1][3]]),ignore_index=True)

df_5 = df_5.append(pd.Series([df_cnn_relu0.iloc[-1][3], df_cnn_relu1.iloc[-1][3], df_cnn_relu2.iloc[-1][3],
                       df_cnn_relu3.iloc[-1][3], df_cnn_relu4.iloc[-1][3], df_cnn_relu5.iloc[-1][3],
                       df_cnn_relu6.iloc[-1][3], df_cnn_relu7.iloc[-1][3], df_cnn_relu8.iloc[-1][3],
                       df_cnn_relu9.iloc[-1][3]]),ignore_index=True)

activator = "relu"

df_cnn_relu0 = pd.read_csv("results/" + activator + "/cnn_K0.csv")
df_cnn_relu1 = pd.read_csv("results/" + activator + "/cnn_K1.csv")
df_cnn_relu2 = pd.read_csv("results/" + activator + "/cnn_K2.csv")
df_cnn_relu3 = pd.read_csv("results/" + activator + "/cnn_K3.csv")
df_cnn_relu4 = pd.read_csv("results/" + activator + "/cnn_K4.csv")
df_cnn_relu5 = pd.read_csv("results/" + activator + "/cnn_K5.csv")
df_cnn_relu6 = pd.read_csv("results/" + activator + "/cnn_K6.csv")
df_cnn_relu7 = pd.read_csv("results/" + activator + "/cnn_K7.csv")
df_cnn_relu8 = pd.read_csv("results/" + activator + "/cnn_K8.csv")
df_cnn_relu9 = pd.read_csv("results/" + activator + "/cnn_K9.csv")

df_1 = df_1.append(pd.Series([df_cnn_relu0.iloc[-1][0], df_cnn_relu1.iloc[-1][0], df_cnn_relu2.iloc[-1][0],
                       df_cnn_relu3.iloc[-1][0], df_cnn_relu4.iloc[-1][0], df_cnn_relu5.iloc[-1][0],
                       df_cnn_relu6.iloc[-1][0], df_cnn_relu7.iloc[-1][0], df_cnn_relu8.iloc[-1][0],
                       df_cnn_relu9.iloc[-1][0]]),ignore_index=True)

df_2 = df_2.append(pd.Series([df_cnn_relu0.iloc[-1][1], df_cnn_relu1.iloc[-1][1], df_cnn_relu2.iloc[-1][1],
                       df_cnn_relu3.iloc[-1][1], df_cnn_relu4.iloc[-1][1], df_cnn_relu5.iloc[-1][1],
                       df_cnn_relu6.iloc[-1][1], df_cnn_relu7.iloc[-1][1], df_cnn_relu8.iloc[-1][1],
                       df_cnn_relu9.iloc[-1][1]]),ignore_index=True)

df_3 = df_3.append(pd.Series([df_cnn_relu0.iloc[-1][2], df_cnn_relu1.iloc[-1][2], df_cnn_relu2.iloc[-1][2],
                       df_cnn_relu3.iloc[-1][2], df_cnn_relu4.iloc[-1][2], df_cnn_relu5.iloc[-1][2],
                       df_cnn_relu6.iloc[-1][2], df_cnn_relu7.iloc[-1][2], df_cnn_relu8.iloc[-1][2],
                       df_cnn_relu9.iloc[-1][2]]),ignore_index=True)

df_4 = df_4.append(pd.Series([df_cnn_relu0.iloc[-1][3], df_cnn_relu1.iloc[-1][3], df_cnn_relu2.iloc[-1][3],
                       df_cnn_relu3.iloc[-1][3], df_cnn_relu4.iloc[-1][3], df_cnn_relu5.iloc[-1][3],
                       df_cnn_relu6.iloc[-1][3], df_cnn_relu7.iloc[-1][3], df_cnn_relu8.iloc[-1][3],
                       df_cnn_relu9.iloc[-1][3]]),ignore_index=True)

df_5 = df_5.append(pd.Series([df_cnn_relu0.iloc[-1][3], df_cnn_relu1.iloc[-1][3], df_cnn_relu2.iloc[-1][3],
                       df_cnn_relu3.iloc[-1][3], df_cnn_relu4.iloc[-1][3], df_cnn_relu5.iloc[-1][3],
                       df_cnn_relu6.iloc[-1][3], df_cnn_relu7.iloc[-1][3], df_cnn_relu8.iloc[-1][3],
                       df_cnn_relu9.iloc[-1][3]]),ignore_index=True)

df_1 = df_1.transpose()
df_1 = df_1.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_2 = df_2.transpose()
df_2 = df_2.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_3 = df_3.transpose()
df_3 = df_3.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_4 = df_4.transpose()
df_4 = df_4.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_5 = df_5.transpose()
df_5 = df_5.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

# %%
rate = 0.4
activator = "sgmd"


df_cnn_relu0 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K0.csv")
df_cnn_relu1 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K1.csv")
df_cnn_relu2 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K2.csv")
df_cnn_relu3 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K3.csv")
df_cnn_relu4 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K4.csv")
df_cnn_relu5 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K5.csv")
df_cnn_relu6 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K6.csv")
df_cnn_relu7 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K7.csv")
df_cnn_relu8 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K8.csv")
df_cnn_relu9 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K9.csv")

df_1_04 = pd.DataFrame(columns=[])
df_2_04 = pd.DataFrame(columns=[])
df_3_04 = pd.DataFrame(columns=[])
df_4_04 = pd.DataFrame(columns=[])
df_5_04 = pd.DataFrame(columns=[])

df_1_04 = df_1_04.append(pd.Series([df_cnn_relu0.iloc[9][0], df_cnn_relu1.iloc[9][0], df_cnn_relu2.iloc[9][0],
                       df_cnn_relu3.iloc[9][0], df_cnn_relu4.iloc[9][0], df_cnn_relu5.iloc[9][0],
                       df_cnn_relu6.iloc[9][0], df_cnn_relu7.iloc[9][0], df_cnn_relu8.iloc[9][0],
                       df_cnn_relu9.iloc[9][0]]),ignore_index=True)

df_2_04 = df_2_04.append(pd.Series([df_cnn_relu0.iloc[9][1], df_cnn_relu1.iloc[9][1], df_cnn_relu2.iloc[9][1],
                       df_cnn_relu3.iloc[9][1], df_cnn_relu4.iloc[9][1], df_cnn_relu5.iloc[9][1],
                       df_cnn_relu6.iloc[9][1], df_cnn_relu7.iloc[9][1], df_cnn_relu8.iloc[9][1],
                       df_cnn_relu9.iloc[9][1]]),ignore_index=True)

df_3_04 = df_3_04.append(pd.Series([df_cnn_relu0.iloc[9][2], df_cnn_relu1.iloc[9][2], df_cnn_relu2.iloc[9][2],
                       df_cnn_relu3.iloc[9][2], df_cnn_relu4.iloc[9][2], df_cnn_relu5.iloc[9][2],
                       df_cnn_relu6.iloc[9][2], df_cnn_relu7.iloc[9][2], df_cnn_relu8.iloc[9][2],
                       df_cnn_relu9.iloc[9][2]]),ignore_index=True)

df_4_04 = df_4_04.append(pd.Series([df_cnn_relu0.iloc[9][3], df_cnn_relu1.iloc[9][3], df_cnn_relu2.iloc[9][3],
                       df_cnn_relu3.iloc[9][3], df_cnn_relu4.iloc[9][3], df_cnn_relu5.iloc[9][3],
                       df_cnn_relu6.iloc[9][3], df_cnn_relu7.iloc[9][3], df_cnn_relu8.iloc[9][3],
                       df_cnn_relu9.iloc[9][3]]),ignore_index=True)

df_5_04 = df_5_04.append(pd.Series([df_cnn_relu0.iloc[9][4], df_cnn_relu1.iloc[9][4], df_cnn_relu2.iloc[9][4],
                       df_cnn_relu3.iloc[9][4], df_cnn_relu4.iloc[9][4], df_cnn_relu5.iloc[9][4],
                       df_cnn_relu6.iloc[9][4], df_cnn_relu7.iloc[9][4], df_cnn_relu8.iloc[9][4],
                       df_cnn_relu9.iloc[9][4]]),ignore_index=True)

activator = "tanh"

df_cnn_relu0 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K0.csv")
df_cnn_relu1 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K1.csv")
df_cnn_relu2 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K2.csv")
df_cnn_relu3 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K3.csv")
df_cnn_relu4 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K4.csv")
df_cnn_relu5 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K5.csv")
df_cnn_relu6 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K6.csv")
df_cnn_relu7 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K7.csv")
df_cnn_relu8 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K8.csv")
df_cnn_relu9 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K9.csv")

df_1_04 = df_1_04.append(pd.Series([df_cnn_relu0.iloc[9][0], df_cnn_relu1.iloc[9][0], df_cnn_relu2.iloc[9][0],
                       df_cnn_relu3.iloc[9][0], df_cnn_relu4.iloc[9][0], df_cnn_relu5.iloc[9][0],
                       df_cnn_relu6.iloc[9][0], df_cnn_relu7.iloc[9][0], df_cnn_relu8.iloc[9][0],
                       df_cnn_relu9.iloc[9][0]]),ignore_index=True)

df_2_04 = df_2_04.append(pd.Series([df_cnn_relu0.iloc[9][1], df_cnn_relu1.iloc[9][1], df_cnn_relu2.iloc[9][1],
                       df_cnn_relu3.iloc[9][1], df_cnn_relu4.iloc[9][1], df_cnn_relu5.iloc[9][1],
                       df_cnn_relu6.iloc[9][1], df_cnn_relu7.iloc[9][1], df_cnn_relu8.iloc[9][1],
                       df_cnn_relu9.iloc[9][1]]),ignore_index=True)

df_3_04 = df_3_04.append(pd.Series([df_cnn_relu0.iloc[9][2], df_cnn_relu1.iloc[9][2], df_cnn_relu2.iloc[9][2],
                       df_cnn_relu3.iloc[9][2], df_cnn_relu4.iloc[9][2], df_cnn_relu5.iloc[9][2],
                       df_cnn_relu6.iloc[9][2], df_cnn_relu7.iloc[9][2], df_cnn_relu8.iloc[9][2],
                       df_cnn_relu9.iloc[9][2]]),ignore_index=True)

df_4_04 = df_4_04.append(pd.Series([df_cnn_relu0.iloc[9][3], df_cnn_relu1.iloc[9][3], df_cnn_relu2.iloc[9][3],
                       df_cnn_relu3.iloc[9][3], df_cnn_relu4.iloc[9][3], df_cnn_relu5.iloc[9][3],
                       df_cnn_relu6.iloc[9][3], df_cnn_relu7.iloc[9][3], df_cnn_relu8.iloc[9][3],
                       df_cnn_relu9.iloc[9][3]]),ignore_index=True)

df_5_04 = df_5_04.append(pd.Series([df_cnn_relu0.iloc[9][4], df_cnn_relu1.iloc[9][4], df_cnn_relu2.iloc[9][4],
                       df_cnn_relu3.iloc[9][4], df_cnn_relu4.iloc[9][4], df_cnn_relu5.iloc[9][4],
                       df_cnn_relu6.iloc[9][4], df_cnn_relu7.iloc[9][4], df_cnn_relu8.iloc[9][4],
                       df_cnn_relu9.iloc[9][4]]),ignore_index=True)

activator = "relu"

df_cnn_relu0 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K0.csv")
df_cnn_relu1 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K1.csv")
df_cnn_relu2 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K2.csv")
df_cnn_relu3 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K3.csv")
df_cnn_relu4 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K4.csv")
df_cnn_relu5 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K5.csv")
df_cnn_relu6 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K6.csv")
df_cnn_relu7 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K7.csv")
df_cnn_relu8 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K8.csv")
df_cnn_relu9 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K9.csv")

df_1_04 = df_1_04.append(pd.Series([df_cnn_relu0.iloc[9][0], df_cnn_relu1.iloc[9][0], df_cnn_relu2.iloc[9][0],
                       df_cnn_relu3.iloc[9][0], df_cnn_relu4.iloc[9][0], df_cnn_relu5.iloc[9][0],
                       df_cnn_relu6.iloc[9][0], df_cnn_relu7.iloc[9][0], df_cnn_relu8.iloc[9][0],
                       df_cnn_relu9.iloc[9][0]]),ignore_index=True)

df_2_04 = df_2_04.append(pd.Series([df_cnn_relu0.iloc[9][1], df_cnn_relu1.iloc[9][1], df_cnn_relu2.iloc[9][1],
                       df_cnn_relu3.iloc[9][1], df_cnn_relu4.iloc[9][1], df_cnn_relu5.iloc[9][1],
                       df_cnn_relu6.iloc[9][1], df_cnn_relu7.iloc[9][1], df_cnn_relu8.iloc[9][1],
                       df_cnn_relu9.iloc[9][1]]),ignore_index=True)

df_3_04 = df_3_04.append(pd.Series([df_cnn_relu0.iloc[9][2], df_cnn_relu1.iloc[9][2], df_cnn_relu2.iloc[9][2],
                       df_cnn_relu3.iloc[9][2], df_cnn_relu4.iloc[9][2], df_cnn_relu5.iloc[9][2],
                       df_cnn_relu6.iloc[9][2], df_cnn_relu7.iloc[9][2], df_cnn_relu8.iloc[9][2],
                       df_cnn_relu9.iloc[9][2]]),ignore_index=True)

df_4_04 = df_4_04.append(pd.Series([df_cnn_relu0.iloc[9][3], df_cnn_relu1.iloc[9][3], df_cnn_relu2.iloc[9][3],
                       df_cnn_relu3.iloc[9][3], df_cnn_relu4.iloc[9][3], df_cnn_relu5.iloc[9][3],
                       df_cnn_relu6.iloc[9][3], df_cnn_relu7.iloc[9][3], df_cnn_relu8.iloc[9][3],
                       df_cnn_relu9.iloc[9][3]]),ignore_index=True)

df_5_04 = df_5_04.append(pd.Series([df_cnn_relu0.iloc[9][4], df_cnn_relu1.iloc[9][4], df_cnn_relu2.iloc[9][4],
                       df_cnn_relu3.iloc[9][4], df_cnn_relu4.iloc[9][4], df_cnn_relu5.iloc[9][4],
                       df_cnn_relu6.iloc[9][4], df_cnn_relu7.iloc[9][4], df_cnn_relu8.iloc[9][4],
                       df_cnn_relu9.iloc[9][4]]),ignore_index=True)

df_1_04 = df_1_04.transpose()
df_1_04 = df_1_04.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_2_04 = df_2_04.transpose()
df_2_04 = df_2_04.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_3_04 = df_3_04.transpose()
df_3_04 = df_3_04.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_4_04 = df_4_04.transpose()
df_4_04 = df_4_04.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_5_04 = df_5_04.transpose()
df_5_04 = df_5_04.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

# %%
rate = 0.6
activator = "sgmd"


df_cnn_relu0 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K0.csv")
df_cnn_relu1 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K1.csv")
df_cnn_relu2 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K2.csv")
df_cnn_relu3 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K3.csv")
df_cnn_relu4 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K4.csv")
df_cnn_relu5 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K5.csv")
df_cnn_relu6 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K6.csv")
df_cnn_relu7 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K7.csv")
df_cnn_relu8 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K8.csv")
df_cnn_relu9 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K9.csv")

df_1_06 = pd.DataFrame(columns=[])
df_2_06 = pd.DataFrame(columns=[])
df_3_06 = pd.DataFrame(columns=[])
df_4_06 = pd.DataFrame(columns=[])
df_5_06 = pd.DataFrame(columns=[])

df_1_06 = df_1_06.append(pd.Series([df_cnn_relu0.iloc[9][0], df_cnn_relu1.iloc[9][0], df_cnn_relu2.iloc[9][0],
                       df_cnn_relu3.iloc[9][0], df_cnn_relu4.iloc[9][0], df_cnn_relu5.iloc[9][0],
                       df_cnn_relu6.iloc[9][0], df_cnn_relu7.iloc[9][0], df_cnn_relu8.iloc[9][0],
                       df_cnn_relu9.iloc[9][0]]),ignore_index=True)

df_2_06 = df_2_06.append(pd.Series([df_cnn_relu0.iloc[9][1], df_cnn_relu1.iloc[9][1], df_cnn_relu2.iloc[9][1],
                       df_cnn_relu3.iloc[9][1], df_cnn_relu4.iloc[9][1], df_cnn_relu5.iloc[9][1],
                       df_cnn_relu6.iloc[9][1], df_cnn_relu7.iloc[9][1], df_cnn_relu8.iloc[9][1],
                       df_cnn_relu9.iloc[9][1]]),ignore_index=True)

df_3_06 = df_3_06.append(pd.Series([df_cnn_relu0.iloc[9][2], df_cnn_relu1.iloc[9][2], df_cnn_relu2.iloc[9][2],
                       df_cnn_relu3.iloc[9][2], df_cnn_relu4.iloc[9][2], df_cnn_relu5.iloc[9][2],
                       df_cnn_relu6.iloc[9][2], df_cnn_relu7.iloc[9][2], df_cnn_relu8.iloc[9][2],
                       df_cnn_relu9.iloc[9][2]]),ignore_index=True)

df_4_06 = df_4_06.append(pd.Series([df_cnn_relu0.iloc[9][3], df_cnn_relu1.iloc[9][3], df_cnn_relu2.iloc[9][3],
                       df_cnn_relu3.iloc[9][3], df_cnn_relu4.iloc[9][3], df_cnn_relu5.iloc[9][3],
                       df_cnn_relu6.iloc[9][3], df_cnn_relu7.iloc[9][3], df_cnn_relu8.iloc[9][3],
                       df_cnn_relu9.iloc[9][3]]),ignore_index=True)

df_5_06 = df_5_06.append(pd.Series([df_cnn_relu0.iloc[9][4], df_cnn_relu1.iloc[9][4], df_cnn_relu2.iloc[9][4],
                       df_cnn_relu3.iloc[9][4], df_cnn_relu4.iloc[9][4], df_cnn_relu5.iloc[9][4],
                       df_cnn_relu6.iloc[9][4], df_cnn_relu7.iloc[9][4], df_cnn_relu8.iloc[9][4],
                       df_cnn_relu9.iloc[9][4]]),ignore_index=True)

activator = "tanh"

df_cnn_relu0 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K0.csv")
df_cnn_relu1 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K1.csv")
df_cnn_relu2 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K2.csv")
df_cnn_relu3 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K3.csv")
df_cnn_relu4 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K4.csv")
df_cnn_relu5 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K5.csv")
df_cnn_relu6 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K6.csv")
df_cnn_relu7 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K7.csv")
df_cnn_relu8 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K8.csv")
df_cnn_relu9 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K9.csv")

df_1_06 = df_1_06.append(pd.Series([df_cnn_relu0.iloc[9][0], df_cnn_relu1.iloc[9][0], df_cnn_relu2.iloc[9][0],
                       df_cnn_relu3.iloc[9][0], df_cnn_relu4.iloc[9][0], df_cnn_relu5.iloc[9][0],
                       df_cnn_relu6.iloc[9][0], df_cnn_relu7.iloc[9][0], df_cnn_relu8.iloc[9][0],
                       df_cnn_relu9.iloc[9][0]]),ignore_index=True)

df_2_06 = df_2_06.append(pd.Series([df_cnn_relu0.iloc[9][1], df_cnn_relu1.iloc[9][1], df_cnn_relu2.iloc[9][1],
                       df_cnn_relu3.iloc[9][1], df_cnn_relu4.iloc[9][1], df_cnn_relu5.iloc[9][1],
                       df_cnn_relu6.iloc[9][1], df_cnn_relu7.iloc[9][1], df_cnn_relu8.iloc[9][1],
                       df_cnn_relu9.iloc[9][1]]),ignore_index=True)

df_3_06 = df_3_06.append(pd.Series([df_cnn_relu0.iloc[9][2], df_cnn_relu1.iloc[9][2], df_cnn_relu2.iloc[9][2],
                       df_cnn_relu3.iloc[9][2], df_cnn_relu4.iloc[9][2], df_cnn_relu5.iloc[9][2],
                       df_cnn_relu6.iloc[9][2], df_cnn_relu7.iloc[9][2], df_cnn_relu8.iloc[9][2],
                       df_cnn_relu9.iloc[9][2]]),ignore_index=True)

df_4_06 = df_4_06.append(pd.Series([df_cnn_relu0.iloc[9][3], df_cnn_relu1.iloc[9][3], df_cnn_relu2.iloc[9][3],
                       df_cnn_relu3.iloc[9][3], df_cnn_relu4.iloc[9][3], df_cnn_relu5.iloc[9][3],
                       df_cnn_relu6.iloc[9][3], df_cnn_relu7.iloc[9][3], df_cnn_relu8.iloc[9][3],
                       df_cnn_relu9.iloc[9][3]]),ignore_index=True)

df_5_06 = df_5_06.append(pd.Series([df_cnn_relu0.iloc[9][4], df_cnn_relu1.iloc[9][4], df_cnn_relu2.iloc[9][4],
                       df_cnn_relu3.iloc[9][4], df_cnn_relu4.iloc[9][4], df_cnn_relu5.iloc[9][4],
                       df_cnn_relu6.iloc[9][4], df_cnn_relu7.iloc[9][4], df_cnn_relu8.iloc[9][4],
                       df_cnn_relu9.iloc[9][4]]),ignore_index=True)

activator = "relu"

df_cnn_relu0 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K0.csv")
df_cnn_relu1 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K1.csv")
df_cnn_relu2 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K2.csv")
df_cnn_relu3 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K3.csv")
df_cnn_relu4 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K4.csv")
df_cnn_relu5 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K5.csv")
df_cnn_relu6 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K6.csv")
df_cnn_relu7 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K7.csv")
df_cnn_relu8 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K8.csv")
df_cnn_relu9 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K9.csv")

df_1_06 = df_1_06.append(pd.Series([df_cnn_relu0.iloc[9][0], df_cnn_relu1.iloc[9][0], df_cnn_relu2.iloc[9][0],
                       df_cnn_relu3.iloc[9][0], df_cnn_relu4.iloc[9][0], df_cnn_relu5.iloc[9][0],
                       df_cnn_relu6.iloc[9][0], df_cnn_relu7.iloc[9][0], df_cnn_relu8.iloc[9][0],
                       df_cnn_relu9.iloc[9][0]]),ignore_index=True)

df_2_06 = df_2_06.append(pd.Series([df_cnn_relu0.iloc[9][1], df_cnn_relu1.iloc[9][1], df_cnn_relu2.iloc[9][1],
                       df_cnn_relu3.iloc[9][1], df_cnn_relu4.iloc[9][1], df_cnn_relu5.iloc[9][1],
                       df_cnn_relu6.iloc[9][1], df_cnn_relu7.iloc[9][1], df_cnn_relu8.iloc[9][1],
                       df_cnn_relu9.iloc[9][1]]),ignore_index=True)

df_3_06 = df_3_06.append(pd.Series([df_cnn_relu0.iloc[9][2], df_cnn_relu1.iloc[9][2], df_cnn_relu2.iloc[9][2],
                       df_cnn_relu3.iloc[9][2], df_cnn_relu4.iloc[9][2], df_cnn_relu5.iloc[9][2],
                       df_cnn_relu6.iloc[9][2], df_cnn_relu7.iloc[9][2], df_cnn_relu8.iloc[9][2],
                       df_cnn_relu9.iloc[9][2]]),ignore_index=True)

df_4_06 = df_4_06.append(pd.Series([df_cnn_relu0.iloc[9][3], df_cnn_relu1.iloc[9][3], df_cnn_relu2.iloc[9][3],
                       df_cnn_relu3.iloc[9][3], df_cnn_relu4.iloc[9][3], df_cnn_relu5.iloc[9][3],
                       df_cnn_relu6.iloc[9][3], df_cnn_relu7.iloc[9][3], df_cnn_relu8.iloc[9][3],
                       df_cnn_relu9.iloc[9][3]]),ignore_index=True)

df_5_06 = df_5_06.append(pd.Series([df_cnn_relu0.iloc[9][4], df_cnn_relu1.iloc[9][4], df_cnn_relu2.iloc[9][4],
                       df_cnn_relu3.iloc[9][4], df_cnn_relu4.iloc[9][4], df_cnn_relu5.iloc[9][4],
                       df_cnn_relu6.iloc[9][4], df_cnn_relu7.iloc[9][4], df_cnn_relu8.iloc[9][4],
                       df_cnn_relu9.iloc[9][4]]),ignore_index=True)

df_1_06 = df_1_06.transpose()
df_1_06 = df_1_06.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_2_06 = df_2_06.transpose()
df_2_06 = df_2_06.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_3_06 = df_3_06.transpose()
df_3_06 = df_3_06.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_4_06 = df_4_06.transpose()
df_4_06 = df_4_06.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_5_06 = df_5_06.transpose()
df_5_06 = df_5_06.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

# %%
rate = 0.8
activator = "sgmd"


df_cnn_relu0 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K0.csv")
df_cnn_relu1 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K1.csv")
df_cnn_relu2 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K2.csv")
df_cnn_relu3 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K3.csv")
df_cnn_relu4 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K4.csv")
df_cnn_relu5 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K5.csv")
df_cnn_relu6 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K6.csv")
df_cnn_relu7 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K7.csv")
df_cnn_relu8 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K8.csv")
df_cnn_relu9 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K9.csv")

df_1_08 = pd.DataFrame(columns=[])
df_2_08 = pd.DataFrame(columns=[])
df_3_08 = pd.DataFrame(columns=[])
df_4_08 = pd.DataFrame(columns=[])
df_5_08 = pd.DataFrame(columns=[])

df_1_08 = df_1_08.append(pd.Series([df_cnn_relu0.iloc[9][0], df_cnn_relu1.iloc[9][0], df_cnn_relu2.iloc[9][0],
                       df_cnn_relu3.iloc[9][0], df_cnn_relu4.iloc[9][0], df_cnn_relu5.iloc[9][0],
                       df_cnn_relu6.iloc[9][0], df_cnn_relu7.iloc[9][0], df_cnn_relu8.iloc[9][0],
                       df_cnn_relu9.iloc[9][0]]),ignore_index=True)

df_2_08 = df_2_08.append(pd.Series([df_cnn_relu0.iloc[9][1], df_cnn_relu1.iloc[9][1], df_cnn_relu2.iloc[9][1],
                       df_cnn_relu3.iloc[9][1], df_cnn_relu4.iloc[9][1], df_cnn_relu5.iloc[9][1],
                       df_cnn_relu6.iloc[9][1], df_cnn_relu7.iloc[9][1], df_cnn_relu8.iloc[9][1],
                       df_cnn_relu9.iloc[9][1]]),ignore_index=True)

df_3_08 = df_3_08.append(pd.Series([df_cnn_relu0.iloc[9][2], df_cnn_relu1.iloc[9][2], df_cnn_relu2.iloc[9][2],
                       df_cnn_relu3.iloc[9][2], df_cnn_relu4.iloc[9][2], df_cnn_relu5.iloc[9][2],
                       df_cnn_relu6.iloc[9][2], df_cnn_relu7.iloc[9][2], df_cnn_relu8.iloc[9][2],
                       df_cnn_relu9.iloc[9][2]]),ignore_index=True)

df_4_08 = df_4_08.append(pd.Series([df_cnn_relu0.iloc[9][3], df_cnn_relu1.iloc[9][3], df_cnn_relu2.iloc[9][3],
                       df_cnn_relu3.iloc[9][3], df_cnn_relu4.iloc[9][3], df_cnn_relu5.iloc[9][3],
                       df_cnn_relu6.iloc[9][3], df_cnn_relu7.iloc[9][3], df_cnn_relu8.iloc[9][3],
                       df_cnn_relu9.iloc[9][3]]),ignore_index=True)

df_5_08 = df_5_08.append(pd.Series([df_cnn_relu0.iloc[9][4], df_cnn_relu1.iloc[9][4], df_cnn_relu2.iloc[9][4],
                       df_cnn_relu3.iloc[9][4], df_cnn_relu4.iloc[9][4], df_cnn_relu5.iloc[9][4],
                       df_cnn_relu6.iloc[9][4], df_cnn_relu7.iloc[9][4], df_cnn_relu8.iloc[9][4],
                       df_cnn_relu9.iloc[9][4]]),ignore_index=True)

activator = "tanh"

df_cnn_relu0 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K0.csv")
df_cnn_relu1 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K1.csv")
df_cnn_relu2 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K2.csv")
df_cnn_relu3 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K3.csv")
df_cnn_relu4 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K4.csv")
df_cnn_relu5 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K5.csv")
df_cnn_relu6 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K6.csv")
df_cnn_relu7 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K7.csv")
df_cnn_relu8 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K8.csv")
df_cnn_relu9 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K9.csv")

df_1_08 = df_1_08.append(pd.Series([df_cnn_relu0.iloc[9][0], df_cnn_relu1.iloc[9][0], df_cnn_relu2.iloc[9][0],
                       df_cnn_relu3.iloc[9][0], df_cnn_relu4.iloc[9][0], df_cnn_relu5.iloc[9][0],
                       df_cnn_relu6.iloc[9][0], df_cnn_relu7.iloc[9][0], df_cnn_relu8.iloc[9][0],
                       df_cnn_relu9.iloc[9][0]]),ignore_index=True)

df_2_08 = df_2_08.append(pd.Series([df_cnn_relu0.iloc[9][1], df_cnn_relu1.iloc[9][1], df_cnn_relu2.iloc[9][1],
                       df_cnn_relu3.iloc[9][1], df_cnn_relu4.iloc[9][1], df_cnn_relu5.iloc[9][1],
                       df_cnn_relu6.iloc[9][1], df_cnn_relu7.iloc[9][1], df_cnn_relu8.iloc[9][1],
                       df_cnn_relu9.iloc[9][1]]),ignore_index=True)

df_3_08 = df_3_08.append(pd.Series([df_cnn_relu0.iloc[9][2], df_cnn_relu1.iloc[9][2], df_cnn_relu2.iloc[9][2],
                       df_cnn_relu3.iloc[9][2], df_cnn_relu4.iloc[9][2], df_cnn_relu5.iloc[9][2],
                       df_cnn_relu6.iloc[9][2], df_cnn_relu7.iloc[9][2], df_cnn_relu8.iloc[9][2],
                       df_cnn_relu9.iloc[9][2]]),ignore_index=True)

df_4_08 = df_4_08.append(pd.Series([df_cnn_relu0.iloc[9][3], df_cnn_relu1.iloc[9][3], df_cnn_relu2.iloc[9][3],
                       df_cnn_relu3.iloc[9][3], df_cnn_relu4.iloc[9][3], df_cnn_relu5.iloc[9][3],
                       df_cnn_relu6.iloc[9][3], df_cnn_relu7.iloc[9][3], df_cnn_relu8.iloc[9][3],
                       df_cnn_relu9.iloc[9][3]]),ignore_index=True)

df_5_08 = df_5_08.append(pd.Series([df_cnn_relu0.iloc[9][4], df_cnn_relu1.iloc[9][4], df_cnn_relu2.iloc[9][4],
                       df_cnn_relu3.iloc[9][4], df_cnn_relu4.iloc[9][4], df_cnn_relu5.iloc[9][4],
                       df_cnn_relu6.iloc[9][4], df_cnn_relu7.iloc[9][4], df_cnn_relu8.iloc[9][4],
                       df_cnn_relu9.iloc[9][4]]),ignore_index=True)

activator = "relu"

df_cnn_relu0 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K0.csv")
df_cnn_relu1 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K1.csv")
df_cnn_relu2 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K2.csv")
df_cnn_relu3 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K3.csv")
df_cnn_relu4 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K4.csv")
df_cnn_relu5 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K5.csv")
df_cnn_relu6 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K6.csv")
df_cnn_relu7 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K7.csv")
df_cnn_relu8 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K8.csv")
df_cnn_relu9 = pd.read_csv("results/dropout/" + str(rate) + "/" + activator + "/cnn_K9.csv")

df_1_08 = df_1_08.append(pd.Series([df_cnn_relu0.iloc[9][0], df_cnn_relu1.iloc[9][0], df_cnn_relu2.iloc[9][0],
                       df_cnn_relu3.iloc[9][0], df_cnn_relu4.iloc[9][0], df_cnn_relu5.iloc[9][0],
                       df_cnn_relu6.iloc[9][0], df_cnn_relu7.iloc[9][0], df_cnn_relu8.iloc[9][0],
                       df_cnn_relu9.iloc[9][0]]),ignore_index=True)

df_2_08 = df_2_08.append(pd.Series([df_cnn_relu0.iloc[9][1], df_cnn_relu1.iloc[9][1], df_cnn_relu2.iloc[9][1],
                       df_cnn_relu3.iloc[9][1], df_cnn_relu4.iloc[9][1], df_cnn_relu5.iloc[9][1],
                       df_cnn_relu6.iloc[9][1], df_cnn_relu7.iloc[9][1], df_cnn_relu8.iloc[9][1],
                       df_cnn_relu9.iloc[9][1]]),ignore_index=True)

df_3_08 = df_3_08.append(pd.Series([df_cnn_relu0.iloc[9][2], df_cnn_relu1.iloc[9][2], df_cnn_relu2.iloc[9][2],
                       df_cnn_relu3.iloc[9][2], df_cnn_relu4.iloc[9][2], df_cnn_relu5.iloc[9][2],
                       df_cnn_relu6.iloc[9][2], df_cnn_relu7.iloc[9][2], df_cnn_relu8.iloc[9][2],
                       df_cnn_relu9.iloc[9][2]]),ignore_index=True)

df_4_08 = df_4_08.append(pd.Series([df_cnn_relu0.iloc[9][3], df_cnn_relu1.iloc[9][3], df_cnn_relu2.iloc[9][3],
                       df_cnn_relu3.iloc[9][3], df_cnn_relu4.iloc[9][3], df_cnn_relu5.iloc[9][3],
                       df_cnn_relu6.iloc[9][3], df_cnn_relu7.iloc[9][3], df_cnn_relu8.iloc[9][3],
                       df_cnn_relu9.iloc[9][3]]),ignore_index=True)

df_5_08 = df_5_08.append(pd.Series([df_cnn_relu0.iloc[9][4], df_cnn_relu1.iloc[9][4], df_cnn_relu2.iloc[9][4],
                       df_cnn_relu3.iloc[9][4], df_cnn_relu4.iloc[9][4], df_cnn_relu5.iloc[9][4],
                       df_cnn_relu6.iloc[9][4], df_cnn_relu7.iloc[9][4], df_cnn_relu8.iloc[9][4],
                       df_cnn_relu9.iloc[9][4]]),ignore_index=True)

df_1_08 = df_1_08.transpose()
df_1_08 = df_1_08.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_2_08 = df_2_08.transpose()
df_2_08 = df_2_08.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_3_08 = df_3_08.transpose()
df_3_08 = df_3_08.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_4_08 = df_4_08.transpose()
df_4_08 = df_4_08.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

df_5_08 = df_5_08.transpose()
df_5_08 = df_5_08.rename(columns={0: "Sigmoid", 1: "Tanh", 2: "RelU"})

# %%
f, axes = plt.subplots(5, 4, figsize=(15, 15), tight_layout=True)
plt.setp(axes, xticks=range(0, 10, 1))

# Value 1
p = sns.lineplot(data=df_1, dashes=False, ax=axes[0, 0])
p.set_title("Eigen Value 1 (No Dropout)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 2
p = sns.lineplot(data=df_2, dashes=False, ax=axes[1, 0])
p.set_title("Eigen Value 2 (No Dropout)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 3
p = sns.lineplot(data=df_3, dashes=False, ax=axes[2, 0])
p.set_title("Eigen Value 3 (No Dropout)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 4
p = sns.lineplot(data=df_4, dashes=False, ax=axes[3, 0])
p.set_title("Eigen Value 4 (No Dropout)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 5
p = sns.lineplot(data=df_5, dashes=False, ax=axes[4, 0])
p.set_title("Eigen Value 5 (No Dropout)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))


###############################################################
# Value 1
p = sns.lineplot(data=df_1_04, dashes=False, ax=axes[0, 1])
p.set_title("Eigen Value 1 (Dropout=0.4)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 2
p = sns.lineplot(data=df_2_04, dashes=False, ax=axes[1, 1])
p.set_title("Eigen Value 2 (Dropout=0.4)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 3
p = sns.lineplot(data=df_3_04, dashes=False, ax=axes[2, 1])
p.set_title("Eigen Value 3 (Dropout=0.4)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 4
p = sns.lineplot(data=df_4_04, dashes=False, ax=axes[3, 1])
p.set_title("Eigen Value 4 (Dropout=0.4)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 5
p = sns.lineplot(data=df_5_04, dashes=False, ax=axes[4, 1])
p.set_title("Eigen Value 5 (Dropout=0.4)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

###############################################################
# Value 1
p = sns.lineplot(data=df_1_06, dashes=False, ax=axes[0, 2])
p.set_title("Eigen Value 1 (Dropout=0.6)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 2
p = sns.lineplot(data=df_2_06, dashes=False, ax=axes[1, 2])
p.set_title("Eigen Value 2 (Dropout=0.6)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 3
p = sns.lineplot(data=df_3_06, dashes=False, ax=axes[2, 2])
p.set_title("Eigen Value 3 (Dropout=0.6)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 4
p = sns.lineplot(data=df_4_06, dashes=False, ax=axes[3, 2])
p.set_title("Eigen Value 4 (Dropout=0.6)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 5
p = sns.lineplot(data=df_5_06, dashes=False, ax=axes[4, 2])
p.set_title("Eigen Value 5 (Dropout=0.6)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

###############################################################
# Value 1
p = sns.lineplot(data=df_1_08, dashes=False, ax=axes[0, 3])
p.set_title("Eigen Value 1 (Dropout=0.8)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 2
p = sns.lineplot(data=df_2_08, dashes=False, ax=axes[1, 3])
p.set_title("Eigen Value 2 (Dropout=0.8)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 3
p = sns.lineplot(data=df_3_08, dashes=False, ax=axes[2, 3])
p.set_title("Eigen Value 3 (Dropout=0.8)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 4
p = sns.lineplot(data=df_4_08, dashes=False, ax=axes[3, 3])
p.set_title("Eigen Value 4 (Dropout=0.8)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')
plt.xticks(range(0, 10, 1))

# Value 5
p = sns.lineplot(data=df_5_08, dashes=False, ax=axes[4, 3])
p.set_title("Eigen Value 5 (Dropout=0.8)")
p.set(xlabel='Kernel Number', ylabel='Eigenvalue')

plt.xticks(range(0, 10, 1))

my_suptitle = f.suptitle("Eigenvalue to Kernel No. ensemble (Dropout)", weight='bold', y=1.02)
f.savefig("Eigenvalue to Kernel No. ensemble (Dropout)" + '.pdf', 
          dpi=f.dpi, bbox_inches='tight',bbox_extra_artists=[my_suptitle])
plt.show()
# Out:
# /home/ajay/development/jax/venv/lib/python3.5/site-packages/matplotlib/figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
# %matplotlib inline

f, axes = plt.subplots(5, 2, figsize=(10, 15), constrained_layout=True)
my_suptitle = f.suptitle('[Classification Error] Correlation Plot: All Datasets', weight='bold', y=1.02)


# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K0.csv")
df_e_1 = pd.read_csv("results/" + activator + "/cnn_test_class_loss.csv")
df_error_1 = pd.DataFrame(columns=["0", "1", "2", "3", "4"])
df_error_1["0"] = df_e_1["0"]
df_error_1["1"] = df_e_1["0"]
df_error_1["2"] = df_e_1["0"]
df_error_1["3"] = df_e_1["0"]
df_error_1["4"] = df_e_1["0"]
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K0.csv")
df_e_2 = pd.read_csv("results/" + activator + "/cnn_test_class_loss.csv")
df_error_2 = pd.DataFrame(columns=["0", "1", "2", "3", "4"])
df_error_2["0"] = df_e_2["0"]
df_error_2["1"] = df_e_2["0"]
df_error_2["2"] = df_e_2["0"]
df_error_2["3"] = df_e_2["0"]
df_error_2["4"] = df_e_2["0"]
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K0.csv")
df_e_3 = pd.read_csv("results/" + activator + "/cnn_test_class_loss.csv")
df_error_3 = pd.DataFrame(columns=["0", "1", "2", "3", "4"])
df_error_3["0"] = df_e_3["0"]
df_error_3["1"] = df_e_3["0"]
df_error_3["2"] = df_e_3["0"]
df_error_3["3"] = df_e_3["0"]
df_error_3["4"] = df_e_3["0"]

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_error_1), df_cnn_relu0_2.corrwith(df_error_2),
                   df_cnn_relu0_1.corrwith(df_error_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd Error", 1: "TanH Error", 2: "Relu Error"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[0, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 0")

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K1.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_error_1), df_cnn_relu0_2.corrwith(df_error_2),
                   df_cnn_relu0_3.corrwith(df_error_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd Error", 1: "TanH Error", 2: "Relu Error"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[0, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 1")

# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K2.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K2.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K2.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_error_1), df_cnn_relu0_2.corrwith(df_error_2),
                   df_cnn_relu0_3.corrwith(df_error_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd Error", 1: "TanH Error", 2: "Relu Error"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[1, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 2")

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K3.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K3.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K3.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_error_1), df_cnn_relu0_2.corrwith(df_error_2),
                   df_cnn_relu0_3.corrwith(df_error_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd Error", 1: "TanH Error", 2: "Relu Error"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[1, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 3")

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K4.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K4.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K4.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_error_1), df_cnn_relu0_2.corrwith(df_error_2),
                   df_cnn_relu0_3.corrwith(df_error_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd Error", 1: "TanH Error", 2: "Relu Error"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[2, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 4")


###############################################################
# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K5.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K5.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K5.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_error_1), df_cnn_relu0_2.corrwith(df_error_2),
                   df_cnn_relu0_3.corrwith(df_error_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd Error", 1: "TanH Error", 2: "Relu Error"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[2, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 5")

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K6.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K6.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K6.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_error_1), df_cnn_relu0_2.corrwith(df_error_2),
                   df_cnn_relu0_3.corrwith(df_error_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd Error", 1: "TanH Error", 2: "Relu Error"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[3, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 6")

# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K7.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K7.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K7.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_error_1), df_cnn_relu0_2.corrwith(df_error_2),
                   df_cnn_relu0_3.corrwith(df_error_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd Error", 1: "TanH Error", 2: "Relu Error"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[3, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 7")

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K8.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K8.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K8.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_error_1), df_cnn_relu0_2.corrwith(df_error_2),
                   df_cnn_relu0_3.corrwith(df_error_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd Error", 1: "TanH Error", 2: "Relu Error"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[4, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 8")

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K9.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K9.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K9.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_error_1), df_cnn_relu0_2.corrwith(df_error_2),
                   df_cnn_relu0_3.corrwith(df_error_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd Error", 1: "TanH Error", 2: "Relu Error"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[4, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 9")

###############################################################

f.savefig("[Classification Error] Correlation Plot: All Datasets" + '.pdf', 
          dpi=f.dpi, bbox_inches='tight',bbox_extra_artists=[my_suptitle])
plt.show()

# %% [markdown]
# # Sigmoid to ReLU to TanH Correlation

# %%
# %matplotlib inline

f, axes = plt.subplots(5, 2, figsize=(10, 15), constrained_layout=True)

# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K0.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K0.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K0.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_cnn_relu0_2), df_cnn_relu0_2.corrwith(df_cnn_relu0_3),
                   df_cnn_relu0_1.corrwith(df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[0, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 0")

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K1.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_cnn_relu0_2), df_cnn_relu0_2.corrwith(df_cnn_relu0_3),
                   df_cnn_relu0_1.corrwith(df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[0, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 1")

# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K2.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K2.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K2.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_cnn_relu0_2), df_cnn_relu0_2.corrwith(df_cnn_relu0_3),
                   df_cnn_relu0_1.corrwith(df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[1, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 2")

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K3.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K3.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K3.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_cnn_relu0_2), df_cnn_relu0_2.corrwith(df_cnn_relu0_3),
                   df_cnn_relu0_1.corrwith(df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[1, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 3")

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K4.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K4.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K4.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_cnn_relu0_2), df_cnn_relu0_2.corrwith(df_cnn_relu0_3),
                   df_cnn_relu0_1.corrwith(df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[2, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 4")


###############################################################
# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K5.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K5.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K5.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_cnn_relu0_2), df_cnn_relu0_2.corrwith(df_cnn_relu0_3),
                   df_cnn_relu0_1.corrwith(df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[2, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 5")

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K6.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K6.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K6.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_cnn_relu0_2), df_cnn_relu0_2.corrwith(df_cnn_relu0_3),
                   df_cnn_relu0_1.corrwith(df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[3, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 6")

# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K7.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K7.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K7.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_cnn_relu0_2), df_cnn_relu0_2.corrwith(df_cnn_relu0_3),
                   df_cnn_relu0_1.corrwith(df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[3, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 7")

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K8.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K8.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K8.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_cnn_relu0_2), df_cnn_relu0_2.corrwith(df_cnn_relu0_3),
                   df_cnn_relu0_1.corrwith(df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[4, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 8")

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K9.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K9.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K9.csv")

df_k1 = pd.concat([df_cnn_relu0_1.corrwith(df_cnn_relu0_2), df_cnn_relu0_2.corrwith(df_cnn_relu0_3),
                   df_cnn_relu0_1.corrwith(df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[4, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 9")

###############################################################

my_suptitle = f.suptitle('Correlation Plot: Sigmoid, TanH & ReLU (No Dropout)', weight='bold', y=1.02)
f.savefig("Correlation Plot: Sigmoid, TanH & ReLU (No Dropout)" + '.pdf', 
          dpi=f.dpi, bbox_inches='tight',bbox_extra_artists=[my_suptitle])
plt.show()

# %% [markdown]
# # Distances between Eigenvalues

# %%
import copy

def calc_dist(df1, df2):
    x = df1.corrwith(df2)
    x[0] = np.linalg.norm(df1['0'][-10:].to_numpy()-df2['0'][-10:].to_numpy())
    x[1] = np.linalg.norm(df1['1'][-10:].to_numpy()-df2['1'][-10:].to_numpy())
    x[2] = np.linalg.norm(df1['2'][-10:].to_numpy()-df2['2'][-10:].to_numpy())
    x[3] = np.linalg.norm(df1['3'][-10:].to_numpy()-df2['3'][-10:].to_numpy())
    x[4] = np.linalg.norm(df1['4'][-10:].to_numpy()-df2['4'][-10:].to_numpy())
    y = copy.deepcopy(x)
    y[0] = np.linalg.norm(np.asarray(x))
    y[1] = np.linalg.norm(np.asarray(x))
    y[2] = np.linalg.norm(np.asarray(x))
    y[3] = np.linalg.norm(np.asarray(x))
    y[4] = np.linalg.norm(np.asarray(x))
    return y

# %%
# %matplotlib inline

f, axes = plt.subplots(5, 2, figsize=(10, 15), constrained_layout=True)

# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K0.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K0.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K0.csv")

df_k1 = pd.concat([calc_dist(df_cnn_relu0_1, df_cnn_relu0_2), calc_dist(df_cnn_relu0_2, df_cnn_relu0_3),
                   calc_dist(df_cnn_relu0_1, df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[0, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 0")

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K1.csv")

df_k1 = pd.concat([calc_dist(df_cnn_relu0_1, df_cnn_relu0_2), calc_dist(df_cnn_relu0_2, df_cnn_relu0_3),
                   calc_dist(df_cnn_relu0_1, df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[0, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 1")

# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K2.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K2.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K2.csv")

df_k1 = pd.concat([calc_dist(df_cnn_relu0_1, df_cnn_relu0_2), calc_dist(df_cnn_relu0_2, df_cnn_relu0_3),
                   calc_dist(df_cnn_relu0_1, df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[1, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 2")

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K3.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K3.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K3.csv")

df_k1 = pd.concat([calc_dist(df_cnn_relu0_1, df_cnn_relu0_2), calc_dist(df_cnn_relu0_2, df_cnn_relu0_3),
                   calc_dist(df_cnn_relu0_1, df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[1, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 3")

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K4.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K4.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K4.csv")

df_k1 = pd.concat([calc_dist(df_cnn_relu0_1, df_cnn_relu0_2), calc_dist(df_cnn_relu0_2, df_cnn_relu0_3),
                   calc_dist(df_cnn_relu0_1, df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[2, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 4")


###############################################################
# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K5.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K5.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K5.csv")

df_k1 = pd.concat([calc_dist(df_cnn_relu0_1, df_cnn_relu0_2), calc_dist(df_cnn_relu0_2, df_cnn_relu0_3),
                   calc_dist(df_cnn_relu0_1, df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[2, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 5")

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K6.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K6.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K6.csv")

df_k1 = pd.concat([calc_dist(df_cnn_relu0_1, df_cnn_relu0_2), calc_dist(df_cnn_relu0_2, df_cnn_relu0_3),
                   calc_dist(df_cnn_relu0_1, df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[3, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 6")

# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K7.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K7.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K7.csv")

df_k1 = pd.concat([calc_dist(df_cnn_relu0_1, df_cnn_relu0_2), calc_dist(df_cnn_relu0_2, df_cnn_relu0_3),
                   calc_dist(df_cnn_relu0_1, df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[3, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 7")

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K8.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K8.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K8.csv")

df_k1 = pd.concat([calc_dist(df_cnn_relu0_1, df_cnn_relu0_2), calc_dist(df_cnn_relu0_2, df_cnn_relu0_3),
                   calc_dist(df_cnn_relu0_1, df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[4, 0], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 8")

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv("results/" + activator + "/cnn_K9.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv("results/" + activator + "/cnn_K9.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv("results/" + activator + "/cnn_K9.csv")

df_k1 = pd.concat([calc_dist(df_cnn_relu0_1, df_cnn_relu0_2), calc_dist(df_cnn_relu0_2, df_cnn_relu0_3),
                   calc_dist(df_cnn_relu0_1, df_cnn_relu0_3)], axis=1)

df_k1 = df_k1.rename(columns={0: "Sgmd to TanH", 1: "TanH to ReLU", 2: "Sgmd to ReLU"})
df_k1 = df_k1.rename(index={"0": "Eigenvalue 1", "1": "Eigenvalue 2", "2": "Eigenvalue 3",
                            "3": "Eigenvalue 4", "4": "Eigenvalue 5"})
p = sns.heatmap(data=df_k1, annot=True, ax=axes[4, 1], annot_kws={"weight": "bold"}, cbar=False)
p.set_title("Kernel 9")

###############################################################

my_suptitle = f.suptitle('Distance Plot: Sigmoid, TanH & ReLU (No Dropout)', weight='bold', y=1.02)
f.savefig("Distance Plot: Sigmoid, TanH & ReLU (No Dropout)" + '.pdf', 
          dpi=f.dpi, bbox_inches='tight',bbox_extra_artists=[my_suptitle])
plt.show()
# Out:
# /home/ajay/development/jax/venv/lib/python3.5/site-packages/jax/lib/xla_bridge.py:119: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')
