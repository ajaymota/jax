# %%
import pandas as pd

# %%
import pandas as pd

dataset = 'mnist'

# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k0_1 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k0_1 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k0_1 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k1_1 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k1_1 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k1_1 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")

sgmd_k2_1 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k2_1 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k2_1 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")

sgmd_k3_1 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k3_1 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k3_1 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")

sgmd_k4_1 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k4_1 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k4_1 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)



###############################################################
# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")

sgmd_k5_1 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k5_1 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k5_1 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")

sgmd_k6_1 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k6_1 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k6_1 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")

sgmd_k7_1 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k7_1 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k7_1 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")

sgmd_k8_1 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k8_1 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k8_1 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")

sgmd_k9_1 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k9_1 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k9_1 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)

# %% [markdown]
# # Hand Sign MNIST

# %%
import pandas as pd

dataset = 'handsign_mnist'

# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k0_2 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k0_2 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k0_2 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k1_2 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k1_2 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k1_2 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")

sgmd_k2_2 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k2_2 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k2_2 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")

sgmd_k3_2 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k3_2 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k3_2 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")

sgmd_k4_2 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k4_2 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k4_2 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)



###############################################################
# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")

sgmd_k5_2 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k5_2 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k5_2 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")

sgmd_k6_2 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k6_2 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k6_2 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")

sgmd_k7_2 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k7_2 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k7_2 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")

sgmd_k8_2 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k8_2 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k8_2 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")

sgmd_k9_2 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k9_2 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k9_2 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)

# %% [markdown]
# # Fashion MNIST

# %%
import pandas as pd

dataset = 'fashion_mnist'

# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k0_3 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k0_3 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k0_3 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)

# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K1.csv")

sgmd_k1_3 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k1_3 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k1_3 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K2.csv")

sgmd_k2_3 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k2_3 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k2_3 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K3.csv")

sgmd_k3_3 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k3_3 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k3_3 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K4.csv")

sgmd_k4_3 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k4_3 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k4_3 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)



###############################################################
# Value 1
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K5.csv")

sgmd_k5_3 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k5_3 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k5_3 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 2
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K6.csv")

sgmd_k6_3 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k6_3 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k6_3 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)


# Value 3
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K7.csv")

sgmd_k7_3 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k7_3 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k7_3 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)

# Value 4
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K8.csv")

sgmd_k8_3 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k8_3 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k8_3 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)

# Value 5
activator = "sgmd"
df_cnn_relu0_1 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "tanh"
df_cnn_relu0_2 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")
activator = "relu"
df_cnn_relu0_3 = pd.read_csv(dataset + "/results/" + activator + "/cnn_K9.csv")

sgmd_k9_3 = df_cnn_relu0_1.corrwith(df_cnn_relu0_2)
tanh_k9_3 = df_cnn_relu0_2.corrwith(df_cnn_relu0_3)
relu_k9_3 = df_cnn_relu0_3.corrwith(df_cnn_relu0_1)

# %% [markdown]
# # Corr-Map (Error Rates)

# %%
import numpy as np

lst = [[sgmd_k0_1.corr(sgmd_k0_2), sgmd_k1_1.corr(sgmd_k1_2), sgmd_k2_1.corr(sgmd_k2_2),
        sgmd_k3_1.corr(sgmd_k3_2), sgmd_k4_1.corr(sgmd_k4_2), sgmd_k5_1.corr(sgmd_k5_2),
        sgmd_k6_1.corr(sgmd_k6_2), sgmd_k7_1.corr(sgmd_k7_2), sgmd_k8_1.corr(sgmd_k8_2),
        sgmd_k9_1.corr(sgmd_k9_2)],
       [sgmd_k0_2.corr(sgmd_k0_3), sgmd_k1_2.corr(sgmd_k1_3), sgmd_k2_2.corr(sgmd_k2_3),
        sgmd_k3_2.corr(sgmd_k3_3), sgmd_k4_2.corr(sgmd_k4_3), sgmd_k5_2.corr(sgmd_k5_3),
        sgmd_k6_2.corr(sgmd_k6_3), sgmd_k7_2.corr(sgmd_k7_3), sgmd_k8_2.corr(sgmd_k8_3),
        sgmd_k9_2.corr(sgmd_k9_3)],
       [sgmd_k0_3.corr(sgmd_k0_1), sgmd_k1_3.corr(sgmd_k1_1), sgmd_k2_3.corr(sgmd_k2_1),
        sgmd_k3_3.corr(sgmd_k3_1), sgmd_k4_3.corr(sgmd_k4_1), sgmd_k5_3.corr(sgmd_k5_1),
        sgmd_k6_3.corr(sgmd_k6_1), sgmd_k7_3.corr(sgmd_k7_1), sgmd_k8_3.corr(sgmd_k8_1),
        sgmd_k9_3.corr(sgmd_k9_1)]]

lst = np.array(lst).T.tolist()

df_1 = pd.DataFrame(lst, columns =[0, 1, 2])  

df_1 = df_1.rename(columns={0: "mnist to hand", 1: "hand to fash", 2: "fash to mnist"})
df_1 = df_1.rename(index={  "0": "Kernel 0", "1": "Kernel 1", "2": "Kernel 2",
                            "3": "Kernel 3", "4": "Kernel 4", "5": "Kernel 5",
                            "6": "Kernel 6", "7": "Kernel 7", "8": "Kernel 8",
                            "9": "Kernel 9"})

print('sgmd to tanh')
df_1
# Out:
# sgmd to tanh
#    mnist to hand  hand to fash  fash to mnist
# 0      -0.403632      0.137884      -0.956839
# 1      -0.403632      0.137884      -0.956839
# 2       0.734721     -0.369588      -0.231327
# 3      -0.201275      0.981172      -0.318790
# 4       0.165626      0.257056      -0.604637
# 5      -0.208366     -0.146188       0.974518
# 6       0.234827      0.044718      -0.951878
# 7      -0.583884     -0.184938      -0.342736
# 8       0.927595      0.900466       0.734969
# 9       0.361963      0.473371      -0.213020

# %%
lst = [[tanh_k0_1.corr(tanh_k0_2), tanh_k1_1.corr(tanh_k1_2), tanh_k2_1.corr(tanh_k2_2),
        tanh_k3_1.corr(tanh_k3_2), tanh_k4_1.corr(tanh_k4_2), tanh_k5_1.corr(tanh_k5_2),
        tanh_k6_1.corr(tanh_k6_2), tanh_k7_1.corr(tanh_k7_2), tanh_k8_1.corr(tanh_k8_2),
        tanh_k9_1.corr(tanh_k9_2)],
       [tanh_k0_2.corr(tanh_k0_3), tanh_k1_2.corr(tanh_k1_3), tanh_k2_2.corr(tanh_k2_3),
        tanh_k3_2.corr(tanh_k3_3), tanh_k4_2.corr(tanh_k4_3), tanh_k5_2.corr(tanh_k5_3),
        tanh_k6_2.corr(tanh_k6_3), tanh_k7_2.corr(tanh_k7_3), tanh_k8_2.corr(tanh_k8_3),
        tanh_k9_2.corr(tanh_k9_3)],
       [tanh_k0_3.corr(tanh_k0_1), tanh_k1_3.corr(tanh_k1_1), tanh_k2_3.corr(tanh_k2_1),
        tanh_k3_3.corr(tanh_k3_1), tanh_k4_3.corr(tanh_k4_1), tanh_k5_3.corr(tanh_k5_1),
        tanh_k6_3.corr(tanh_k6_1), tanh_k7_3.corr(tanh_k7_1), tanh_k8_3.corr(tanh_k8_1),
        tanh_k9_3.corr(tanh_k9_1)]]

lst = np.array(lst).T.tolist()

df_2 = pd.DataFrame(lst, columns =[0, 1, 2])  

df_2 = df_2.rename(columns={0: "mnist to hand", 1: "hand to fash", 2: "fash to mnist"})
df_2 = df_2.rename(index={"0": "Kernel 0", "1": "Kernel 1", "2": "Kernel 2",
                            "3": "Kernel 3", "4": "Kernel 4", "5": "Kernel 5",
                            "6": "Kernel 6", "7": "Kernel 7", "8": "Kernel 8",
                            "9": "Kernel 9"})

print('tanh to relu')
df_2
# Out:
# tanh to relu
#    mnist to hand  hand to fash  fash to mnist
# 0       0.149358      0.595253       0.653116
# 1       0.149358      0.595253       0.653116
# 2       0.502159     -0.758229      -0.268610
# 3      -0.665097     -0.845255       0.248624
# 4      -0.490167     -0.274749       0.907788
# 5      -0.421438      0.524406      -0.275960
# 6      -0.592553      0.394635      -0.545031
# 7      -0.673714     -0.359846       0.095895
# 8       0.942196     -0.360884      -0.387304
# 9       0.142981     -0.982232       0.014048

# %%
lst = [[relu_k0_1.corr(relu_k0_2), relu_k1_1.corr(relu_k1_2), relu_k2_1.corr(relu_k2_2),
        relu_k3_1.corr(relu_k3_2), relu_k4_1.corr(relu_k4_2), relu_k5_1.corr(relu_k5_2),
        relu_k6_1.corr(relu_k6_2), relu_k7_1.corr(relu_k7_2), relu_k8_1.corr(relu_k8_2),
        relu_k9_1.corr(relu_k9_2)],
       [relu_k0_2.corr(relu_k0_3), relu_k1_2.corr(relu_k1_3), relu_k2_2.corr(relu_k2_3),
        relu_k3_2.corr(relu_k3_3), relu_k4_2.corr(relu_k4_3), relu_k5_2.corr(relu_k5_3),
        relu_k6_2.corr(relu_k6_3), relu_k7_2.corr(relu_k7_3), relu_k8_2.corr(relu_k8_3),
        relu_k9_2.corr(relu_k9_3)],
       [relu_k0_3.corr(relu_k0_1), relu_k1_3.corr(relu_k1_1), relu_k2_3.corr(relu_k2_1),
        relu_k3_3.corr(relu_k3_1), relu_k4_3.corr(relu_k4_1), relu_k5_3.corr(relu_k5_1),
        relu_k6_3.corr(relu_k6_1), relu_k7_3.corr(relu_k7_1), relu_k8_3.corr(relu_k8_1),
        relu_k9_3.corr(relu_k9_1)]]

lst = np.array(lst).T.tolist()

df_3 = pd.DataFrame(lst, columns =[0, 1, 2])  

df_3 = df_3.rename(columns={0: "mnist to hand", 1: "hand to fash", 2: "fash to mnist"})
df_3 = df_3.rename(index={"0": "Kernel 0", "1": "Kernel 1", "2": "Kernel 2",
                            "3": "Kernel 3", "4": "Kernel 4", "5": "Kernel 5",
                            "6": "Kernel 6", "7": "Kernel 7", "8": "Kernel 8",
                            "9": "Kernel 9"})

print('relu to sgmd')
df_3
# Out:
# relu to sgmd
#    mnist to hand  hand to fash  fash to mnist
# 0       0.824420      0.725746       0.237263
# 1       0.824420      0.725746       0.237263
# 2       0.466902     -0.297423      -0.527707
# 3      -0.449075     -0.633538       0.763278
# 4       0.269327      0.232388       0.942591
# 5      -0.153297     -0.735622      -0.514908
# 6       0.635733     -0.413207      -0.965435
# 7      -0.543427     -0.568040       0.471779
# 8       0.837036      0.176796       0.116468
# 9       0.995774     -0.263306      -0.228409

# %%
print("Corr: (Dist) sgmd to tanh")
print()
print('mnist to hand: ', df_1['mnist to hand'].abs().mean())
print('hand to fash: ', df_1['hand to fash'].abs().mean())
print('fash to mnist: ', df_1['fash to mnist'].abs().mean())
print()
print()

print("Corr: (Dist) tanh to relu")
print()
print('mnist to hand: ', df_2['mnist to hand'].abs().mean())
print('hand to fash: ', df_2['hand to fash'].abs().mean())
print('fash to mnist: ', df_2['fash to mnist'].abs().mean())
print()
print()

print("Corr: (Dist) relu to sgmd")
print()
print('mnist to hand: ', df_3['mnist to hand'].abs().mean())
print('hand to fash: ', df_3['hand to fash'].abs().mean())
print('fash to mnist: ', df_3['fash to mnist'].abs().mean())
print()
print()
# Out:
# Dist: sgmd to tanh
#
# mnist to hand:  0.42255210568952845
# hand to fash:  0.36332636529433265
# fash to mnist:  0.6285555188701374
#
#
# Dist: tanh to relu
#
# mnist to hand:  0.47290208719168997
# hand to fash:  0.5690740898891467
# fash to mnist:  0.40494934233538177
#
#
# Dist: relu to sgmd
#
# mnist to hand:  0.5999410465425953
# hand to fash:  0.4771811356846677
# fash to mnist:  0.5005102592821741

# %%
# print(df_1['mnist to hand'].corr(df_2['mnist to hand']))
# print(df_1['hand to fash'].corr(df_2['hand to fash']))
# print(df_1['fash to mnist'].corr(df_2['fash to mnist']))

# %%
# print(df_2['mnist to hand'].corr(df_3['mnist to hand']))
# print(df_2['hand to fash'].corr(df_3['hand to fash']))
# print(df_2['fash to mnist'].corr(df_3['fash to mnist']))

# %%
# print(df_3['mnist to hand'].corr(df_1['mnist to hand']))
# print(df_3['hand to fash'].corr(df_1['hand to fash']))
# print(df_3['fash to mnist'].corr(df_1['fash to mnist']))
