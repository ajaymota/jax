# %%
import pandas as pd
from matplotlib import pyplot as plt
import jax.numpy as np
import seaborn as sns

# %%
df_cnn_relu_train = pd.read_csv("results/dropout/cnn_relu_train_loss.csv")
df_cnn_relu_test = pd.read_csv("results/dropout/cnn_relu_test_loss.csv")
df_cnn_relu_test_class = pd.read_csv("results/dropout/cnn_relu_test_class_loss.csv")

# %%
df_cnn_relu_train['train'] = df_cnn_relu_train
df_cnn_relu_train['test'] = df_cnn_relu_test
df_cnn_relu_train['classification'] = df_cnn_relu_test_class
df_cnn_relu_train.drop('0', axis=1, inplace=True)

# %%
p = sns.lineplot(data=df_cnn_relu_train, dashes=False)
p.set_title("Error - train v/s test v/s classification")
p.set(xlabel='epchocs', ylabel='error')
plt.legend(bbox_to_anchor=(1.05, 1), title="type", loc=2, borderaxespad=0.)
plt.show()

# %%
df_cnn_relu0 = pd.read_csv("results/dropout/cnn_relu_K0.csv")
df_cnn_relu1 = pd.read_csv("results/dropout/cnn_relu_K1.csv")
df_cnn_relu2 = pd.read_csv("results/dropout/cnn_relu_K2.csv")
df_cnn_relu3 = pd.read_csv("results/dropout/cnn_relu_K3.csv")
df_cnn_relu4 = pd.read_csv("results/dropout/cnn_relu_K4.csv")
df_cnn_relu5 = pd.read_csv("results/dropout/cnn_relu_K5.csv")
df_cnn_relu6 = pd.read_csv("results/dropout/cnn_relu_K6.csv")
df_cnn_relu7 = pd.read_csv("results/dropout/cnn_relu_K7.csv")
df_cnn_relu8 = pd.read_csv("results/dropout/cnn_relu_K8.csv")
df_cnn_relu9 = pd.read_csv("results/dropout/cnn_relu_K9.csv")

# %%
p = sns.lineplot(data=df_cnn_relu0, dashes=False)
p.set_title("ReLU Kernel 1")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu1, dashes=False)
p.set_title("ReLU Kernel 2")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu2, dashes=False)
p.set_title("ReLU Kernel 3")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu3, dashes=False)
p.set_title("ReLU Kernel 4")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu4, dashes=False)
p.set_title("ReLU Kernel 5")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu5, dashes=False)
p.set_title("ReLU Kernel 6")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu6, dashes=False)
p.set_title("ReLU Kernel 7")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu7, dashes=False)
p.set_title("ReLU Kernel 8")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu8, dashes=False)
p.set_title("ReLU Kernel 9")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
p = sns.lineplot(data=df_cnn_relu9, dashes=False)
p.set_title("ReLU Kernel 10")
p.set(xlabel='epochs', ylabel='eigenvalues')
p.legend(bbox_to_anchor=(1.05, 1), title="n-th eigenvalue", loc=2, borderaxespad=0.)

plt.show()

# %%
print(df_cnn_relu0['0'].corr(df_cnn_relu_train['classification']) )
print(df_cnn_relu0['1'].corr(df_cnn_relu_train['classification']) )
print(df_cnn_relu0['2'].corr(df_cnn_relu_train['classification']) )
print(df_cnn_relu0['3'].corr(df_cnn_relu_train['classification']) )
print(df_cnn_relu0['4'].corr(df_cnn_relu_train['classification']) )
# Out:
# 0.9495860946767826
# 0.9915458518024374
# 0.8711086559541327
# -0.952305723903454
# -0.7723328522813458

# %%
df_cnn_relu0.corrwith(df_cnn_relu9, axis=0)
# Out:
# 0   -0.999294
# 1    0.955579
# 2   -0.983160
# 3    0.999671
# 4    0.424521
# dtype: float64
